# %%
import xenaPython
import pandas as pd

# %%
hub = "https://toil.xenahubs.net"
dataset = "tcga_RSEM_gene_tpm"
samples = ["TCGA-02-0047-01","TCGA-02-0055-01","TCGA-02-2483-01","TCGA-02-2485-01"]
probes = ['ENSG00000282740.1', 'ENSG00000000005.5', 'ENSG00000000419.12']
[position, [ENSG00000282740_1, ENSG00000000005_5, ENSG00000000419_12]] = xenaPython.dataset_probe_values(hub, dataset, samples, probes)
ENSG00000282740_1
# Out:
# [-9.966, -2.826, -9.966, -9.966]
