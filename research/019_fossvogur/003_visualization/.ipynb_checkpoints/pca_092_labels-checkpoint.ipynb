# %%
import pandas, numpy, scipy

# %%
import sklearn, sklearn.preprocessing, sklearn.decomposition

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(2/3), 9*(2/3)), 
                            'axes.labelsize':20
                           })

# %% [markdown]
# # 0. user-defined variables

# %%
input_file = '/Users/adrian/research/bmcbf/019_fossvogur/002_quantification/DESeq2_TPM_values.tsv'

# %% [markdown]
# # 1. read expression

# %%
expression = pandas.read_csv(input_file, sep='\t', index_col=0)
print(expression.shape)
expression
# Out:
# (39546, 31)
#                  501-KO13_VHN-10  501-KO13_VHN-2  501-KO13_VHN-6    C1_RD-10  \
# ENSG00000000003        19.954768       16.072870       17.216985   12.573916
# ENSG00000000005         0.000000        0.000000        0.000000    0.006439
# ENSG00000000419       213.351825      154.868847      171.142164  151.675645
# ENSG00000000457         6.972656        5.472320        5.674427    5.102438
# ENSG00000000460        34.320934       30.989133       31.857731   34.709662
# ...                          ...             ...             ...         ...
# ENSG00000291297         5.551173        8.142017        5.234141    5.888645
# ENSG00000291298         0.000000        0.000000        0.000000    0.000000
# ENSG00000291299         1.063779        2.764225        1.930863    2.019971
# ENSG00000291300         0.000000        0.000000        0.000000    0.000000
# ENSG00000291301         0.000000        0.000000        0.000000    0.000000
#
# ...

# %%
expression.columns
# Out:
# Index(['501-KO13_VHN-10', '501-KO13_VHN-2', '501-KO13_VHN-6', 'C1_RD-10',
#        'C1_RD-4', 'C1-RD-16', 'C3_RD-1', 'C3_RD-13', 'C3_RD-7', 'KO13_VHN-11',
#        'KO13_VHN-3', 'KO13_VHN-7', 'KO17_VHN-12', 'KO17_VHN-4', 'KO17_VHN-8',
#        'KO24_VHN-1', 'KO24_VHN-5', 'KO24_VHN-9', 'siCTRL_1', 'siCTRL_2',
#        'siCTRL_3', 'siMITF_1', 'siMITF_2', 'siMITF_3',
#        'SkMel28-MITFKO_ev_skmel28_rep1', 'SkMel28-MITFKO_ev_skmel28_rep2',
#        'SkMel28-MITFKO_ev_skmel28_rep3', 'SkMel28-MITFKO_ev_skmel28_rep4',
#        'SkMel28-MITFKO_mitf_x6_rep1', 'SkMel28-MITFKO_mitf_x6_rep3',
#        'SkMel28-MITFKO_mitf_x6_rep4'],
#       dtype='str')

# %%
for element in expression.columns:
    print(element)
# Out:
# 501-KO13_VHN-10
# 501-KO13_VHN-2
# 501-KO13_VHN-6
# C1_RD-10
# C1_RD-4
# C1-RD-16
# C3_RD-1
# C3_RD-13
# C3_RD-7
# KO13_VHN-11
# KO13_VHN-3
# KO13_VHN-7
# KO17_VHN-12
# KO17_VHN-4
# KO17_VHN-8
# KO24_VHN-1
# KO24_VHN-5
# KO24_VHN-9
# siCTRL_1
# siCTRL_2
# siCTRL_3
# siMITF_1
# siMITF_2
# siMITF_3
# SkMel28-MITFKO_ev_skmel28_rep1
# SkMel28-MITFKO_ev_skmel28_rep2
# SkMel28-MITFKO_ev_skmel28_rep3
# SkMel28-MITFKO_ev_skmel28_rep4
# SkMel28-MITFKO_mitf_x6_rep1
# SkMel28-MITFKO_mitf_x6_rep3
# SkMel28-MITFKO_mitf_x6_rep4

# %% [markdown]
# # 3. filter and transform

# %%
substantial_expression = expression[expression.max(axis=1) >= 2]
high_expression = expression[expression.max(axis=1) >= 100]

print(substantial_expression.shape)
print(high_expression.shape)
# Out:
# (15081, 31)
# (2860, 31)

# %%
transpose = substantial_expression.transpose()
pca_substantial_expression = numpy.log2(transpose + 1)

transpose = high_expression.transpose()
pca_high_expression = numpy.log2(transpose + 1)

# %% [markdown]
# # 4. visualize substantial expression

# %%
scaled_data = sklearn.preprocessing.StandardScaler().fit_transform(pca_substantial_expression)
model = sklearn.decomposition.PCA(n_components=2)
new = model.fit_transform(scaled_data)
explained = model.explained_variance_ratio_
print(explained)
# Out:
# [0.41021882 0.15235867]

# %%
#my_colors = ['gold']*3 + ['skyblue']*3 + ['tab:red']*3 + ['black']*3 + ['tab:green']*3
#my_markers = ['o']*9 + ['s']*6

#legend_elements = [
    
#    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='gold', markeredgecolor='white', markersize=20, alpha=2/3),
#    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='skyblue', markeredgecolor='white', markersize=20, alpha=2/3),
#    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='tab:red', markeredgecolor='white', markersize=20, alpha=2/3),
#    matplotlib.lines.Line2D([0], [0], color='white', marker='s', markerfacecolor='black', markeredgecolor='white', markersize=20, alpha=2/3),
#    matplotlib.lines.Line2D([0], [0], color='white', marker='s', markerfacecolor='tab:green', markeredgecolor='white', markersize=20, alpha=2/3)
#    
#]

# %%
for i in range(len(new)):
    #matplotlib.pyplot.scatter(new[i,0], new[i,1], s=666, c=my_colors[i], marker=my_markers[i], alpha=2/3, edgecolors='none')
    matplotlib.pyplot.scatter(new[i,0], new[i,1], s=666, c='black', marker='o', alpha=2/3, edgecolors='none')

#matplotlib.pyplot.legend(legend_elements, ['h1', 'h2 low', 'h2 high', 'KO', 'WT'], ncol=2, loc='upper left', bbox_to_anchor=(1.05, 1))
    
matplotlib.pyplot.xlabel('PC1 (exp. var.: {}%)'.format(int(explained[0]*100)))
matplotlib.pyplot.ylabel('PC2 (exp. var.: {}%)'.format(int(explained[1]*100)))
matplotlib.pyplot.grid(alpha=0.5, ls=':')

matplotlib.pyplot.show()
#matplotlib.pyplot.savefig('pca.svg')

# %%
for i in range(len(new)):
    #matplotlib.pyplot.scatter(new[i,0], new[i,1], s=666, c=my_colors[i], marker=my_markers[i], alpha=2/3, edgecolors='none')
    matplotlib.pyplot.scatter(new[i,0], new[i,1], s=666, c='black', marker='o', alpha=2/3, edgecolors='none')

    epsilon = 4
    matplotlib.pyplot.text(new[i,0]+epsilon, new[i,1]+epsilon, expression.columns[i], size=12)

#matplotlib.pyplot.legend(legend_elements, ['h1', 'h2 low', 'h2 high', 'KO', 'WT'], ncol=2, loc='upper left', bbox_to_anchor=(1.05, 1))
    
matplotlib.pyplot.xlabel('PC1 (exp. var.: {}%)'.format(int(explained[0]*100)))
matplotlib.pyplot.ylabel('PC2 (exp. var.: {}%)'.format(int(explained[1]*100)))
matplotlib.pyplot.grid(alpha=0.5, ls=':')

# %% [markdown]
# # 4. visualize high expression

# %%
scaled_data = sklearn.preprocessing.StandardScaler().fit_transform(pca_high_expression)
model = sklearn.decomposition.PCA(n_components=2)
new = model.fit_transform(scaled_data)
explained = model.explained_variance_ratio_
print(explained)
# Out:
# [0.4484785  0.17061121]

# %%
labels_501 = [
    '501-KO13_VHN-10', '501-KO13_VHN-2', '501-KO13_VHN-6',   # ko prdm7 in 501
    'C1_RD-10', 'C1_RD-4', 'C1-RD-16',                        # wt 501
    'KO24_VHN-1', 'KO24_VHN-5', 'KO24_VHN-9',                 # ko prdm7 in 501, clone II
    'siCTRL_1', 'siCTRL_2', 'siCTRL_3',                       # wt 501
    'siMITF_1', 'siMITF_2', 'siMITF_3',                       # kd MITF in 501
]

labels_skmel28 = [
    'C3_RD-1', 'C3_RD-13', 'C3_RD-7',                                    # skmel28 wt
    'KO13_VHN-11', 'KO13_VHN-3', 'KO13_VHN-7',                           # ko prdm7 in skmel28
    'KO17_VHN-12', 'KO17_VHN-4', 'KO17_VHN-8',                           # ko prdm7 clone 2, skmel28
    'SkMel28-MITFKO_ev_skmel28_rep1', 'SkMel28-MITFKO_ev_skmel28_rep2',
    'SkMel28-MITFKO_ev_skmel28_rep3', 'SkMel28-MITFKO_ev_skmel28_rep4',  # ev control, skmel28
    'SkMel28-MITFKO_mitf_x6_rep1', 'SkMel28-MITFKO_mitf_x6_rep3',
    'SkMel28-MITFKO_mitf_x6_rep4',                                       # ko mitf, skmel28
]

labels_wt = [
    'C1_RD-10', 'C1_RD-4', 'C1-RD-16',                    # wt 501
    'C3_RD-1', 'C3_RD-13', 'C3_RD-7',                     # skmel28 wt
    'siCTRL_1', 'siCTRL_2', 'siCTRL_3',                   # wt 501 (siRNA control)
    'SkMel28-MITFKO_ev_skmel28_rep1', 'SkMel28-MITFKO_ev_skmel28_rep2',
    'SkMel28-MITFKO_ev_skmel28_rep3', 'SkMel28-MITFKO_ev_skmel28_rep4',  # empty vector, ~wt
]

labels_ko = [
    '501-KO13_VHN-10', '501-KO13_VHN-2', '501-KO13_VHN-6',   # ko prdm7, 501
    'KO24_VHN-1', 'KO24_VHN-5', 'KO24_VHN-9',                 # ko prdm7, 501, clone II
    'KO13_VHN-11', 'KO13_VHN-3', 'KO13_VHN-7',                # ko prdm7, skmel28
    'KO17_VHN-12', 'KO17_VHN-4', 'KO17_VHN-8',                # ko prdm7 clone 2, skmel28
    'SkMel28-MITFKO_mitf_x6_rep1', 'SkMel28-MITFKO_mitf_x6_rep3',
    'SkMel28-MITFKO_mitf_x6_rep4',                            # ko mitf, skmel28
]

labels_kd = ['siMITF_1', 'siMITF_2', 'siMITF_3']

# %%
for i in range(len(new)):

    name = pca_high_expression.index[i]
    
    # colors
    if name in labels_skmel28:
        the_color = 'tab:orange'
    elif name in labels_501:
        the_color = 'tab:blue'
    else:
        print('error a')

    # markers
    if name in labels_wt:
        the_marker = 'o'
    elif name in labels_ko:
        the_marker = '*'
    elif name in labels_kd:
        the_marker = 's'
    else:
        print(name)
        print('error b')
    
    epsilon = 1
    matplotlib.pyplot.scatter(new[i,0], new[i,1], s=200, c=the_color, marker=the_marker, alpha=2/3, edgecolors='none')
    matplotlib.pyplot.text(new[i,0]+epsilon, new[i,1]+epsilon, expression.columns[i], size=12)


    legend_elements = [
        matplotlib.patches.Rectangle((0, 0), 1.8, 1, facecolor='tab:orange',      edgecolor='white', alpha=2/3),
        matplotlib.patches.Rectangle((0, 0), 1.8, 1, facecolor='tab:blue',    edgecolor='white', alpha=2/3)
    ]    
    matplotlib.pyplot.legend(legend_elements, ['skmel', '501'], 
                             ncol=1, loc='upper left', bbox_to_anchor=(1.05, 1))
    
matplotlib.pyplot.xlabel('PC1 (exp. var.: {}%)'.format(int(explained[0]*100)))
matplotlib.pyplot.ylabel('PC2 (exp. var.: {}%)'.format(int(explained[1]*100)))
matplotlib.pyplot.grid(alpha=0.5, ls=':')
matplotlib.pyplot.show()

# %% [markdown]
# ### distributions

# %%
log2_tpm_PO = numpy.log2(expression + 1)
log2_tpm_PO.head()
# Out:
#                  501-KO13_VHN-10  501-KO13_VHN-2  501-KO13_VHN-6  C1_RD-10  \
# ENSG00000000003         4.389207        4.093634        4.187212  3.762765
# ENSG00000000005         0.000000        0.000000        0.000000  0.009260
# ENSG00000000419         7.743837        7.284189        7.427457  7.254326
# ENSG00000000457         2.995060        2.694283        2.738644  2.609386
# ENSG00000000460         5.142452        4.999510        5.038161  5.158243
#
#                   C1_RD-4  C1-RD-16   C3_RD-1  C3_RD-13   C3_RD-7  \
# ENSG00000000003  3.962448  3.732825  3.380945  3.537947  3.431936
# ENSG00000000005  0.000000  0.000000  0.000000  0.000000  0.000000
# ENSG00000000419  7.247582  7.342222  7.350778  7.710940  7.504165
# ENSG00000000457  2.744541  2.614637  2.248939  2.219819  2.421649
# ENSG00000000460  5.366074  5.326306  4.409306  4.378272  4.222351
#
#                  KO13_VHN-11  ...  siMITF_1  siMITF_2  siMITF_3  \
# ...

# %%
found_max = 14.1
number_of_bins = int(found_max*10)
print(number_of_bins)

absolute_max = 0
working_samples = log2_tpm_PO.columns.to_list()

for i in range(len(working_samples)):

    name = working_samples[i]

    # colors
    if 'KO13' in name:
        the_color = 'tab:red'
    elif 'C1' in name:
        the_color = 'black'
    elif 'KO24' in name:
        the_color = 'tab:orange'
    else:
        print('error')
        
    log2TPM = log2_tpm_PO.loc[:, name]
    if max(log2TPM) > absolute_max:
        absolute_max = max(log2TPM)
                
    hist, bin_edges = numpy.histogram(log2TPM, bins=number_of_bins, range=(0, found_max))
    half_bin = (bin_edges[1] - bin_edges[0])/2
    x = bin_edges + half_bin
    x = x[:-1]
  
    plotting_x = x[5:-20]
    plotting_hist = hist[5:-20]
    
    #matplotlib.pyplot.plot(plotting_x, plotting_hist, 'o', alpha=1/5, mec='none', color=the_color)
    yhat = scipy.signal.savgol_filter(plotting_hist, 51, 3)

    matplotlib.pyplot.plot(plotting_x, yhat, '-', lw=2, alpha=2/3, color=the_color)
    
matplotlib.pyplot.xlim([numpy.min(plotting_x)-0.25, numpy.max(plotting_x)+0.25])

legend_elements = [
        matplotlib.patches.Rectangle((0, 0), 1.8, 1, facecolor='tab:red',      edgecolor='white', alpha=2/3),
        matplotlib.patches.Rectangle((0, 0), 1.8, 1, facecolor='tab:orange',    edgecolor='white', alpha=2/3),
        matplotlib.patches.Rectangle((0, 0), 1.8, 1, facecolor='black',    edgecolor='white', alpha=2/3)
    ]    
matplotlib.pyplot.legend(legend_elements, ['KO13', 'KO24', 'CTRL'], 
                             ncol=1, loc='upper left', bbox_to_anchor=(1.05, 1))

matplotlib.pyplot.xlabel('log2 (TPM+1)')
matplotlib.pyplot.ylabel('Gene count')
matplotlib.pyplot.grid(ls=':')

matplotlib.pyplot.tight_layout()

print(absolute_max)
# Out:
# 141
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 15.402799429881497
