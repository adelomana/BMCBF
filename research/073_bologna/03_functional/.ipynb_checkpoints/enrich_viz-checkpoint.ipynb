# %%
import pandas, numpy

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(1/3), 9*(4/3)), 
                            'axes.labelsize':20
                           })
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
enrichments_file = '/Users/adrian/research/bmcbf/073_bologna/results/enrichment/clusterProfiler_enrichments.tsv'
enrichments_file = '/Users/adrian/research/bmcbf/073_bologna/results/enrichment/clusterProfiler_enrichments.together.tsv'

# %%
df = pandas.read_csv(enrichments_file, sep='\t')
df
# Out:
#        Cluster             ID                                  Description  \
# 1     D7 vs D0  R-HSA-1474244            Extracellular matrix organization
# 2     D7 vs D0  R-HSA-1474290                           Collagen formation
# 3     D7 vs D0  R-HSA-1474228      Degradation of the extracellular matrix
# 4     D7 vs D0   R-HSA-216083           Integrin cell surface interactions
# 5     D7 vs D0  R-HSA-3000178                            ECM proteoglycans
# ..         ...            ...                                          ...
# 120  D21 vs D7  R-HSA-1650814  Collagen biosynthesis and modifying enzymes
# 121  D21 vs D7  R-HSA-8875878                   MET promotes cell motility
# 122  D21 vs D7  R-HSA-3000170                        Syndecan interactions
# 123  D21 vs D7    R-HSA-75892        Platelet Adhesion to exposed collagen
# 124  D21 vs D7  R-HSA-9671793                       Diseases of hemostasis
#
#     GeneRatio    BgRatio  RichFactor  FoldEnrichment     zScore        pvalue  \
# 1      95/988  321/11214    0.295950        3.359094  13.329398  1.202305e-27
# 2      32/988   90/11214    0.355556        4.035628   8.987228  1.736845e-12
# 3      39/988  140/11214    0.278571        3.161842   8.000594  4.013961e-11
# 4      28/988   85/11214    0.329412        3.738890   7.878481  3.355006e-10
# 5      26/988   76/11214    0.342105        3.882964   7.838427  5.634150e-10
# ..        ...        ...         ...             ...        ...           ...
# 120     8/247   67/11214    0.119403        5.420992   5.446827  1.050430e-04
# 121     6/247   41/11214    0.146341        6.644021   5.433268  2.531208e-04
# 122     5/247   27/11214    0.185185        8.407557   5.783165  2.702698e-04
# 123     4/247   16/11214    0.250000       11.350202   6.217332  3.393280e-04
# 124     4/247   19/11214    0.210526        9.558065   5.602809  6.860297e-04
#
#          p.adjust        qvalue  \
# 1    1.625516e-24  1.480733e-24
# 2    1.174107e-09  1.069531e-09
# 3    1.808959e-08  1.647837e-08
# 4    1.133992e-07  1.032989e-07
# 5    1.376864e-07  1.254228e-07
# ..            ...           ...
# 120  4.061661e-03  3.785759e-03
# 121  9.342459e-03  8.707840e-03
# 122  9.541699e-03  8.893547e-03
# 123  1.148060e-02  1.070074e-02
# 124  2.228224e-02  2.076865e-02
#
#                                                 geneID  Count
# 1    2006/2192/1311/3908/3690/1634/1404/222663/1513...     95
# 2    4015/1295/4314/7373/1301/140766/1514/1281/4017...     32
# 3    2006/1634/222663/1513/9507/1295/4314/7373/1301...     39
# 4    1311/3690/3673/1295/960/6696/1281/3675/3678/12...     28
# 5    1311/3908/3690/1634/1404/3673/1281/54829/3910/...     26
# ..                                                 ...    ...
# 120           1281/1278/1277/1284/1282/1287/81578/1300      8
# 121                     1281/1278/1277/3675/3914/10319      6
# 122                           1281/1278/1277/6382/3691      5
# 123                                1278/1277/8515/7450      4
# 124                                1278/1277/2159/7450      4
#
# [124 rows x 13 columns]

# %%
contrasts = []
for element in df['Cluster']:
    if element not in contrasts:
        contrasts.append(element)

print(contrasts)
# Out:
# ['D7 vs D0', 'D28 vs D7', 'D21 vs D7']

# %%
terms_to_use = []
top_ten_categories = []
for contrast in contrasts:
    
    print(contrast)
    sub = df[df['Cluster'] == contrast]
    all_observed_gene_lists = []
    contrast_terms = []
    top_ten = []
    
    for index, row in sub.iterrows():
        
        
        genes = row['geneID'].split('/')
        print('\t', row['ID'], row['Description'], len(genes))
        
        # checking the overlap
        overlap = False
        max_overlap = 0
        for element in all_observed_gene_lists:
            intersect = list(set(element) & set(genes))
            relative_intersect = len(intersect)/len(genes)
            #print('\t\t\t intersect is', len(intersect), relative_intersect)
            if max_overlap < relative_intersect:
                max_overlap = relative_intersect
            if relative_intersect > 0.9:
                overlap=True
            
        all_observed_gene_lists.append(genes)

        #print('\t', overlap)
        #print()
        if overlap == False:
            print('\t accepting', row['ID'], row['Description'], 'because overlap is', max_overlap)
            contrast_terms.append(row['ID'])
            if len(contrast_terms) <= 10:
                top_ten.append(row['ID'])
        else:
            print('\t rejecting', row['ID'], row['Description'], 'because overlap is', max_overlap)
        print()

    # end of contrast
    terms_to_use.append(contrast_terms)
    top_ten_categories.append(top_ten)
    print()
    #print(terms_to_use)
# Out:
# D7 vs D0
# 	 R-HSA-1474244 Extracellular matrix organization 95
# 	 accepting R-HSA-1474244 Extracellular matrix organization because overlap is 0
#
# 	 R-HSA-1474290 Collagen formation 32
# 	 rejecting R-HSA-1474290 Collagen formation because overlap is 1.0
#
# 	 R-HSA-1474228 Degradation of the extracellular matrix 39
# 	 rejecting R-HSA-1474228 Degradation of the extracellular matrix because overlap is 1.0
#
# 	 R-HSA-216083 Integrin cell surface interactions 28
# 	 rejecting R-HSA-216083 Integrin cell surface interactions because overlap is 1.0
#
# 	 R-HSA-3000178 ECM proteoglycans 26
# 	 rejecting R-HSA-3000178 ECM proteoglycans because overlap is 1.0
#
# 	 R-HSA-2022090 Assembly of collagen fibrils and other multimeric structures 23
# 	 rejecting R-HSA-2022090 Assembly of collagen fibrils and other multimeric structures because overlap is 1.0
#
# 	 R-HSA-3000157 Laminin interactions 15
# 	 rejecting R-HSA-3000157 Laminin interactions because overlap is 1.0
#
# 	 R-HSA-1566948 Elastic fibre formation 18
# 	 rejecting R-HSA-1566948 Elastic fibre formation because overlap is 1.0
#
# 	 R-HSA-3000171 Non-integrin membrane-ECM interactions 25
# 	 rejecting R-HSA-3000171 Non-integrin membrane-ECM interactions because overlap is 1.0
#
# 	 R-HSA-1442490 Collagen degradation 22
# 	 rejecting R-HSA-1442490 Collagen degradation because overlap is 1.0
#
# 	 R-HSA-6785807 Interleukin-4 and Interleukin-13 signaling 29
# 	 accepting R-HSA-6785807 Interleukin-4 and Interleukin-13 signaling because overlap is 0.20689655172413793
#
# 	 R-HSA-1650814 Collagen biosynthesis and modifying enzymes 21
# 	 rejecting R-HSA-1650814 Collagen biosynthesis and modifying enzymes because overlap is 1.0
#
# 	 R-HSA-3560782 Diseases associated with glycosaminoglycan metabolism 16
# 	 accepting R-HSA-3560782 Diseases associated with glycosaminoglycan metabolism because overlap is 0.5625
#
# 	 R-HSA-381426 Regulation of Insulin-like Growth Factor (IGF) transport and uptake by Insulin-like Growth Factor Binding Proteins (IGFBPs) 30
# 	 accepting R-HSA-381426 Regulation of Insulin-like Growth Factor (IGF) transport and uptake by Insulin-like Growth Factor Binding Proteins (IGFBPs) because overlap is 0.2
#
# 	 R-HSA-8874081 MET activates PTK2 signaling 13
# 	 rejecting R-HSA-8874081 MET activates PTK2 signaling because overlap is 0.9230769230769231
#
# 	 R-HSA-114608 Platelet degranulation 30
# 	 accepting R-HSA-114608 Platelet degranulation because overlap is 0.3
#
# 	 R-HSA-9694614 Attachment and Entry 10
# 	 accepting R-HSA-9694614 Attachment and Entry because overlap is 0.8
#
# 	 R-HSA-76005 Response to elevated platelet cytosolic Ca2+ 30
# 	 rejecting R-HSA-76005 Response to elevated platelet cytosolic Ca2+ because overlap is 1.0
#
# 	 R-HSA-8957275 Post-translational protein phosphorylation 26
# 	 rejecting R-HSA-8957275 Post-translational protein phosphorylation because overlap is 1.0
#
# 	 R-HSA-8948216 Collagen chain trimerization 15
# 	 rejecting R-HSA-8948216 Collagen chain trimerization because overlap is 1.0
#
# 	 R-HSA-198725 Nuclear Events (kinase and transcription factor activation) 18
# 	 accepting R-HSA-198725 Nuclear Events (kinase and transcription factor activation) because overlap is 0.1111111111111111
#
# 	 R-HSA-76002 Platelet activation, signaling and aggregation 46
# 	 accepting R-HSA-76002 Platelet activation, signaling and aggregation because overlap is 0.6521739130434783
#
# 	 R-HSA-191273 Cholesterol biosynthesis 11
# 	 accepting R-HSA-191273 Cholesterol biosynthesis because overlap is 0
#
# 	 R-HSA-2129379 Molecules associated with elastic fibres 13
# 	 rejecting R-HSA-2129379 Molecules associated with elastic fibres because overlap is 1.0
#
# 	 R-HSA-9925563 Developmental Lineage of Pancreatic Ductal Cells 15
# 	 accepting R-HSA-9925563 Developmental Lineage of Pancreatic Ductal Cells because overlap is 0.6666666666666666
#
# 	 R-HSA-1630316 Glycosaminoglycan metabolism 27
# 	 accepting R-HSA-1630316 Glycosaminoglycan metabolism because overlap is 0.5925925925925926
#
# 	 R-HSA-9031628 NGF-stimulated transcription 13
# 	 rejecting R-HSA-9031628 NGF-stimulated transcription because overlap is 1.0
#
# 	 R-HSA-202733 Cell surface interactions at the vascular wall 28
# 	 accepting R-HSA-202733 Cell surface interactions at the vascular wall because overlap is 0.42857142857142855
#
# 	 R-HSA-3781865 Diseases of glycosylation 29
# 	 accepting R-HSA-3781865 Diseases of glycosylation because overlap is 0.5517241379310345
#
# 	 R-HSA-3560783 Defective B4GALT7 causes EDS, progeroid type 9
# 	 rejecting R-HSA-3560783 Defective B4GALT7 causes EDS, progeroid type because overlap is 1.0
#
# 	 R-HSA-3560801 Defective B3GAT3 causes JDSSDHD 9
# 	 rejecting R-HSA-3560801 Defective B3GAT3 causes JDSSDHD because overlap is 1.0
#
# 	 R-HSA-4420332 Defective B3GALT6 causes EDSP2 and SEMDJL1 9
# 	 rejecting R-HSA-4420332 Defective B3GALT6 causes EDSP2 and SEMDJL1 because overlap is 1.0
#
# 	 R-HSA-8875878 MET promotes cell motility 13
# 	 rejecting R-HSA-8875878 MET promotes cell motility because overlap is 1.0
#
# 	 R-HSA-166520 Signaling by NTRKs 27
# 	 accepting R-HSA-166520 Signaling by NTRKs because overlap is 0.6666666666666666
#
# 	 R-HSA-2022928 HS-GAG biosynthesis 11
# 	 rejecting R-HSA-2022928 HS-GAG biosynthesis because overlap is 1.0
#
# 	 R-HSA-187037 Signaling by NTRK1 (TRKA) 24
# 	 rejecting R-HSA-187037 Signaling by NTRK1 (TRKA) because overlap is 1.0
#
# 	 R-HSA-1592389 Activation of Matrix Metalloproteinases 11
# 	 rejecting R-HSA-1592389 Activation of Matrix Metalloproteinases because overlap is 1.0
#
# 	 R-HSA-3656237 Defective EXT2 causes exostoses 2 7
# 	 rejecting R-HSA-3656237 Defective EXT2 causes exostoses 2 because overlap is 1.0
#
# 	 R-HSA-3656253 Defective EXT1 causes exostoses 1, TRPS2 and CHDS 7
# 	 rejecting R-HSA-3656253 Defective EXT1 causes exostoses 1, TRPS2 and CHDS because overlap is 1.0
#
# 	 R-HSA-9820960 Respiratory syncytial virus (RSV) attachment and entry 9
# 	 accepting R-HSA-9820960 Respiratory syncytial virus (RSV) attachment and entry because overlap is 0.8888888888888888
#
# 	 R-HSA-6783589 Interleukin-6 family signaling 9
# 	 accepting R-HSA-6783589 Interleukin-6 family signaling because overlap is 0.4444444444444444
#
# 	 R-HSA-449147 Signaling by Interleukins 64
# 	 accepting R-HSA-449147 Signaling by Interleukins because overlap is 0.453125
#
# 	 R-HSA-9913351 Formation of the dystrophin-glycoprotein complex (DGC) 11
# 	 rejecting R-HSA-9913351 Formation of the dystrophin-glycoprotein complex (DGC) because overlap is 1.0
#
# 	 R-HSA-112316 Neuronal System 58
# 	 accepting R-HSA-112316 Neuronal System because overlap is 0.08620689655172414
#
# 	 R-HSA-500792 GPCR ligand binding 64
# 	 accepting R-HSA-500792 GPCR ligand binding because overlap is 0.109375
#
# 	 R-HSA-373760 L1CAM interactions 23
# 	 accepting R-HSA-373760 L1CAM interactions because overlap is 0.30434782608695654
#
# 	 R-HSA-418990 Adherens junctions interactions 14
# 	 accepting R-HSA-418990 Adherens junctions interactions because overlap is 0.07142857142857142
#
# 	 R-HSA-1971475 A tetrasaccharide linker sequence is required for GAG synthesis 9
# 	 rejecting R-HSA-1971475 A tetrasaccharide linker sequence is required for GAG synthesis because overlap is 1.0
#
# 	 R-HSA-3000170 Syndecan interactions 9
# 	 rejecting R-HSA-3000170 Syndecan interactions because overlap is 1.0
#
# 	 R-HSA-6788467 IL-6-type cytokine receptor ligand interactions 7
# 	 rejecting R-HSA-6788467 IL-6-type cytokine receptor ligand interactions because overlap is 1.0
#
# 	 R-HSA-9856532 Mechanical load activates signaling by PIEZO1 and integrins in osteocytes 7
# 	 accepting R-HSA-9856532 Mechanical load activates signaling by PIEZO1 and integrins in osteocytes because overlap is 0.5714285714285714
#
# 	 R-HSA-112315 Transmission across Chemical Synapses 41
# 	 rejecting R-HSA-112315 Transmission across Chemical Synapses because overlap is 1.0
#
# 	 R-HSA-140877 Formation of Fibrin Clot (Clotting Cascade) 11
# 	 accepting R-HSA-140877 Formation of Fibrin Clot (Clotting Cascade) because overlap is 0.5454545454545454
#
# 	 R-HSA-5576891 Cardiac conduction 24
# 	 accepting R-HSA-5576891 Cardiac conduction because overlap is 0.25
#
# 	 R-HSA-397014 Muscle contraction 33
# 	 accepting R-HSA-397014 Muscle contraction because overlap is 0.7272727272727273
#
# 	 R-HSA-5668914 Diseases of metabolism 39
# 	 accepting R-HSA-5668914 Diseases of metabolism because overlap is 0.7435897435897436
#
# 	 R-HSA-416700 Other semaphorin interactions 7
# 	 accepting R-HSA-416700 Other semaphorin interactions because overlap is 0
#
# 	 R-HSA-5083635 Defective B3GALTL causes PpS 10
# 	 rejecting R-HSA-5083635 Defective B3GALTL causes PpS because overlap is 1.0
#
# 	 R-HSA-2022857 Keratan sulfate degradation 6
# 	 rejecting R-HSA-2022857 Keratan sulfate degradation because overlap is 1.0
#
# 	 R-HSA-2162123 Synthesis of Prostaglandins (PG) and Thromboxanes (TX) 6
# 	 accepting R-HSA-2162123 Synthesis of Prostaglandins (PG) and Thromboxanes (TX) because overlap is 0.16666666666666666
#
# 	 R-HSA-2214320 Anchoring fibril formation 6
# 	 rejecting R-HSA-2214320 Anchoring fibril formation because overlap is 1.0
#
# 	 R-HSA-1793185 Chondroitin sulfate/dermatan sulfate metabolism 12
# 	 rejecting R-HSA-1793185 Chondroitin sulfate/dermatan sulfate metabolism because overlap is 1.0
#
# 	 R-HSA-5173214 O-glycosylation of TSR domain-containing proteins 10
# 	 rejecting R-HSA-5173214 O-glycosylation of TSR domain-containing proteins because overlap is 1.0
#
# 	 R-HSA-9772572 Early SARS-CoV-2 Infection Events 10
# 	 rejecting R-HSA-9772572 Early SARS-CoV-2 Infection Events because overlap is 1.0
#
# 	 R-HSA-1638091 Heparan sulfate/heparin (HS-GAG) metabolism 13
# 	 rejecting R-HSA-1638091 Heparan sulfate/heparin (HS-GAG) metabolism because overlap is 1.0
#
# 	 R-HSA-373080 Class B/2 (Secretin family receptors) 18
# 	 rejecting R-HSA-373080 Class B/2 (Secretin family receptors) because overlap is 1.0
#
# 	 R-HSA-2586552 Signaling by Leptin 5
# 	 rejecting R-HSA-2586552 Signaling by Leptin because overlap is 1.0
#
# 	 R-HSA-9855142 Cellular responses to mechanical stimuli 19
# 	 accepting R-HSA-9855142 Cellular responses to mechanical stimuli because overlap is 0.3684210526315789
#
# 	 R-HSA-446728 Cell junction organization 20
# 	 accepting R-HSA-446728 Cell junction organization because overlap is 0.7
#
# 	 R-HSA-2142845 Hyaluronan metabolism 6
# 	 rejecting R-HSA-2142845 Hyaluronan metabolism because overlap is 1.0
#
# 	 R-HSA-373076 Class A/1 (Rhodopsin-like receptors) 45
# 	 rejecting R-HSA-373076 Class A/1 (Rhodopsin-like receptors) because overlap is 1.0
#
# 	 R-HSA-9009391 Extra-nuclear estrogen signaling 15
# 	 accepting R-HSA-9009391 Extra-nuclear estrogen signaling because overlap is 0.4
#
#
# D28 vs D7
# 	 R-HSA-3000157 Laminin interactions 10
# 	 accepting R-HSA-3000157 Laminin interactions because overlap is 0
#
# 	 R-HSA-8874081 MET activates PTK2 signaling 10
# 	 accepting R-HSA-8874081 MET activates PTK2 signaling because overlap is 0.6
#
# 	 R-HSA-3000178 ECM proteoglycans 15
# 	 accepting R-HSA-3000178 ECM proteoglycans because overlap is 0.4666666666666667
#
# 	 R-HSA-9925563 Developmental Lineage of Pancreatic Ductal Cells 12
# 	 accepting R-HSA-9925563 Developmental Lineage of Pancreatic Ductal Cells because overlap is 0.6666666666666666
#
# 	 R-HSA-3000171 Non-integrin membrane-ECM interactions 15
# 	 accepting R-HSA-3000171 Non-integrin membrane-ECM interactions because overlap is 0.6666666666666666
#
# 	 R-HSA-2173782 Binding and Uptake of Ligands by Scavenger Receptors 11
# 	 accepting R-HSA-2173782 Binding and Uptake of Ligands by Scavenger Receptors because overlap is 0.45454545454545453
#
# 	 R-HSA-2214320 Anchoring fibril formation 7
# 	 rejecting R-HSA-2214320 Anchoring fibril formation because overlap is 1.0
#
# 	 R-HSA-1474244 Extracellular matrix organization 32
# 	 accepting R-HSA-1474244 Extracellular matrix organization because overlap is 0.46875
#
# 	 R-HSA-8875878 MET promotes cell motility 10
# 	 rejecting R-HSA-8875878 MET promotes cell motility because overlap is 1.0
#
# 	 R-HSA-9734767 Developmental Cell Lineages 17
# 	 accepting R-HSA-9734767 Developmental Cell Lineages because overlap is 0.7058823529411765
#
# 	 R-HSA-3000480 Scavenging by Class A Receptors 7
# 	 rejecting R-HSA-3000480 Scavenging by Class A Receptors because overlap is 1.0
#
# 	 R-HSA-9820448 Developmental Cell Lineages of the Exocrine Pancreas 13
# 	 rejecting R-HSA-9820448 Developmental Cell Lineages of the Exocrine Pancreas because overlap is 1.0
#
# 	 R-HSA-1474228 Degradation of the extracellular matrix 17
# 	 rejecting R-HSA-1474228 Degradation of the extracellular matrix because overlap is 1.0
#
# 	 R-HSA-6806834 Signaling by MET 12
# 	 accepting R-HSA-6806834 Signaling by MET because overlap is 0.8333333333333334
#
# 	 R-HSA-186797 Signaling by PDGF 10
# 	 accepting R-HSA-186797 Signaling by PDGF because overlap is 0.7
#
# 	 R-HSA-2022090 Assembly of collagen fibrils and other multimeric structures 10
# 	 rejecting R-HSA-2022090 Assembly of collagen fibrils and other multimeric structures because overlap is 1.0
#
# 	 R-HSA-6809371 Formation of the cornified envelope 15
# 	 accepting R-HSA-6809371 Formation of the cornified envelope because overlap is 0.2
#
# 	 R-HSA-1442490 Collagen degradation 10
# 	 rejecting R-HSA-1442490 Collagen degradation because overlap is 1.0
#
# 	 R-HSA-69273 Cyclin A/B1/B2 associated events during G2/M transition 7
# 	 accepting R-HSA-69273 Cyclin A/B1/B2 associated events during G2/M transition because overlap is 0
#
# 	 R-HSA-8948216 Collagen chain trimerization 8
# 	 rejecting R-HSA-8948216 Collagen chain trimerization because overlap is 1.0
#
# 	 R-HSA-156711 Polo-like kinase mediated events 5
# 	 accepting R-HSA-156711 Polo-like kinase mediated events because overlap is 0.8
#
# 	 R-HSA-216083 Integrin cell surface interactions 11
# 	 rejecting R-HSA-216083 Integrin cell surface interactions because overlap is 1.0
#
# 	 R-HSA-6791312 TP53 Regulates Transcription of Cell Cycle Genes 8
# 	 accepting R-HSA-6791312 TP53 Regulates Transcription of Cell Cycle Genes because overlap is 0.375
#
# 	 R-HSA-2243919 Crosslinking of collagen fibrils 5
# 	 rejecting R-HSA-2243919 Crosslinking of collagen fibrils because overlap is 1.0
#
# 	 R-HSA-3000170 Syndecan interactions 6
# 	 rejecting R-HSA-3000170 Syndecan interactions because overlap is 1.0
#
# 	 R-HSA-3560782 Diseases associated with glycosaminoglycan metabolism 7
# 	 accepting R-HSA-3560782 Diseases associated with glycosaminoglycan metabolism because overlap is 0.42857142857142855
#
# 	 R-HSA-419037 NCAM1 interactions 7
# 	 accepting R-HSA-419037 NCAM1 interactions because overlap is 0.7142857142857143
#
#
# D21 vs D7
# 	 R-HSA-1474244 Extracellular matrix organization 27
# 	 accepting R-HSA-1474244 Extracellular matrix organization because overlap is 0
#
# 	 R-HSA-3000171 Non-integrin membrane-ECM interactions 12
# 	 rejecting R-HSA-3000171 Non-integrin membrane-ECM interactions because overlap is 1.0
#
# 	 R-HSA-3000157 Laminin interactions 8
# 	 rejecting R-HSA-3000157 Laminin interactions because overlap is 1.0
#
# 	 R-HSA-2173782 Binding and Uptake of Ligands by Scavenger Receptors 9
# 	 accepting R-HSA-2173782 Binding and Uptake of Ligands by Scavenger Receptors because overlap is 0.5555555555555556
#
# 	 R-HSA-216083 Integrin cell surface interactions 12
# 	 rejecting R-HSA-216083 Integrin cell surface interactions because overlap is 1.0
#
# 	 R-HSA-2214320 Anchoring fibril formation 6
# 	 rejecting R-HSA-2214320 Anchoring fibril formation because overlap is 1.0
#
# 	 R-HSA-9648895 Response of EIF2AK1 (HRI) to heme deficiency 6
# 	 accepting R-HSA-9648895 Response of EIF2AK1 (HRI) to heme deficiency because overlap is 0
#
# 	 R-HSA-9925563 Developmental Lineage of Pancreatic Ductal Cells 9
# 	 accepting R-HSA-9925563 Developmental Lineage of Pancreatic Ductal Cells because overlap is 0.5555555555555556
#
# 	 R-HSA-9734767 Developmental Cell Lineages 13
# 	 accepting R-HSA-9734767 Developmental Cell Lineages because overlap is 0.6923076923076923
#
# 	 R-HSA-3000480 Scavenging by Class A Receptors 6
# 	 rejecting R-HSA-3000480 Scavenging by Class A Receptors because overlap is 1.0
#
# 	 R-HSA-1474228 Degradation of the extracellular matrix 14
# 	 rejecting R-HSA-1474228 Degradation of the extracellular matrix because overlap is 1.0
#
# 	 R-HSA-8948216 Collagen chain trimerization 8
# 	 rejecting R-HSA-8948216 Collagen chain trimerization because overlap is 1.0
#
# 	 R-HSA-3000178 ECM proteoglycans 10
# 	 rejecting R-HSA-3000178 ECM proteoglycans because overlap is 1.0
#
# 	 R-HSA-2022090 Assembly of collagen fibrils and other multimeric structures 9
# 	 rejecting R-HSA-2022090 Assembly of collagen fibrils and other multimeric structures because overlap is 1.0
#
# 	 R-HSA-1474290 Collagen formation 10
# 	 rejecting R-HSA-1474290 Collagen formation because overlap is 1.0
#
# 	 R-HSA-2243919 Crosslinking of collagen fibrils 5
# 	 rejecting R-HSA-2243919 Crosslinking of collagen fibrils because overlap is 1.0
#
# 	 R-HSA-8874081 MET activates PTK2 signaling 6
# 	 rejecting R-HSA-8874081 MET activates PTK2 signaling because overlap is 1.0
#
# 	 R-HSA-1442490 Collagen degradation 8
# 	 rejecting R-HSA-1442490 Collagen degradation because overlap is 1.0
#
# 	 R-HSA-9820448 Developmental Cell Lineages of the Exocrine Pancreas 9
# 	 rejecting R-HSA-9820448 Developmental Cell Lineages of the Exocrine Pancreas because overlap is 1.0
#
# 	 R-HSA-176974 Unwinding of DNA 4
# 	 accepting R-HSA-176974 Unwinding of DNA because overlap is 0
#
# 	 R-HSA-1650814 Collagen biosynthesis and modifying enzymes 8
# 	 rejecting R-HSA-1650814 Collagen biosynthesis and modifying enzymes because overlap is 1.0
#
# 	 R-HSA-8875878 MET promotes cell motility 6
# 	 rejecting R-HSA-8875878 MET promotes cell motility because overlap is 1.0
#
# 	 R-HSA-3000170 Syndecan interactions 5
# 	 rejecting R-HSA-3000170 Syndecan interactions because overlap is 1.0
#
# 	 R-HSA-75892 Platelet Adhesion to exposed collagen 4
# 	 rejecting R-HSA-75892 Platelet Adhesion to exposed collagen because overlap is 1.0
#
# 	 R-HSA-9671793 Diseases of hemostasis 4
# 	 accepting R-HSA-9671793 Diseases of hemostasis because overlap is 0.75

# %%
for content in terms_to_use:
    print(len(content), content)

print()

for top_ten in top_ten_categories:
    print(len(top_ten), top_ten)

union_list = list(set(item for sublist in top_ten_categories for item in sublist))

print()

print(len(union_list), union_list)
# Out:
# 31 ['R-HSA-1474244', 'R-HSA-6785807', 'R-HSA-3560782', 'R-HSA-381426', 'R-HSA-114608', 'R-HSA-9694614', 'R-HSA-198725', 'R-HSA-76002', 'R-HSA-191273', 'R-HSA-9925563', 'R-HSA-1630316', 'R-HSA-202733', 'R-HSA-3781865', 'R-HSA-166520', 'R-HSA-9820960', 'R-HSA-6783589', 'R-HSA-449147', 'R-HSA-112316', 'R-HSA-500792', 'R-HSA-373760', 'R-HSA-418990', 'R-HSA-9856532', 'R-HSA-140877', 'R-HSA-5576891', 'R-HSA-397014', 'R-HSA-5668914', 'R-HSA-416700', 'R-HSA-2162123', 'R-HSA-9855142', 'R-HSA-446728', 'R-HSA-9009391']
# 16 ['R-HSA-3000157', 'R-HSA-8874081', 'R-HSA-3000178', 'R-HSA-9925563', 'R-HSA-3000171', 'R-HSA-2173782', 'R-HSA-1474244', 'R-HSA-9734767', 'R-HSA-6806834', 'R-HSA-186797', 'R-HSA-6809371', 'R-HSA-69273', 'R-HSA-156711', 'R-HSA-6791312', 'R-HSA-3560782', 'R-HSA-419037']
# 7 ['R-HSA-1474244', 'R-HSA-2173782', 'R-HSA-9648895', 'R-HSA-9925563', 'R-HSA-9734767', 'R-HSA-176974', 'R-HSA-9671793']
#
# 10 ['R-HSA-1474244', 'R-HSA-6785807', 'R-HSA-3560782', 'R-HSA-381426', 'R-HSA-114608', 'R-HSA-9694614', 'R-HSA-198725', 'R-HSA-76002', 'R-HSA-191273', 'R-HSA-9925563']
# 10 ['R-HSA-3000157', 'R-HSA-8874081', 'R-HSA-3000178', 'R-HSA-9925563', 'R-HSA-3000171', 'R-HSA-2173782', 'R-HSA-1474244', 'R-HSA-9734767', 'R-HSA-6806834', 'R-HSA-186797']
# 7 ['R-HSA-1474244', 'R-HSA-2173782', 'R-HSA-9648895', 'R-HSA-9925563', 'R-HSA-9734767', 'R-HSA-176974', 'R-HSA-9671793']
#
# 21 ['R-HSA-191273', 'R-HSA-9925563', 'R-HSA-176974', 'R-HSA-9734767', 'R-HSA-9671793', 'R-HSA-3000178', 'R-HSA-1474244', 'R-HSA-8874081', 'R-HSA-3560782', 'R-HSA-6806834', 'R-HSA-76002', 'R-HSA-3000157', 'R-HSA-3000171', 'R-HSA-9694614', 'R-HSA-9648895', 'R-HSA-186797', 'R-HSA-381426', 'R-HSA-114608', 'R-HSA-2173782', 'R-HSA-198725', 'R-HSA-6785807']

# %%
terms_used_so_far = {}
depth = 0
print(terms_to_use)
factor_size_circles = 10
for i in range(len(terms_to_use)):
    for j in range(len(terms_to_use[i])):
        element = terms_to_use[i][j]

        if element in union_list:
        
            if element in terms_used_so_far.keys():
                location = terms_used_so_far[element]
            else:
                depth = depth - 1
                location = depth
    
            # define color
            adjp = -numpy.log10(df[(df['ID'] == element) & (df['Cluster'] == contrasts[i])]['p.adjust'].values[0])
            #print(element, adjp)
    
            # define size
            thesize = int(df[(df['ID'] == element) & (df['Cluster'] == contrasts[i])]['GeneRatio'].values[0].split('/')[0])
            
            # make a point        
            matplotlib.pyplot.scatter(i, location, s=thesize*factor_size_circles, c=adjp, zorder=9999, cmap='cividis', vmin=-numpy.log10(0.05), vmax=15)
            terms_used_so_far[element] = location
            print(location, element)


matplotlib.pyplot.colorbar(label='-log10 adj. P', ticks=[5, 10, 15])

# close the figure
a = []; b = []
for element in terms_used_so_far.keys():
    description = list(df[df['ID'] == element]['Description'].values)[0]
    a.append(description)
    b.append(terms_used_so_far[element])

for area in factor_size_circles*numpy.array([5, 25, 50]):
    matplotlib.pyplot.scatter([], [], c='black', edgecolor=None, s=area, label=str(int(area/factor_size_circles)))
matplotlib.pyplot.legend(loc=3)

matplotlib.pyplot.yticks(b, a, fontsize=12)
matplotlib.pyplot.xticks(list(range(len(contrasts))), 
                         contrasts, 
                         rotation=-90)

#matplotlib.pyplot.ylim(-40.75, -0.25)
matplotlib.pyplot.grid(ls=':')
matplotlib.pyplot.tight_layout()

#matplotlib.pyplot.show()
matplotlib.pyplot.savefig('enrichment.svg')
# Out:
# [['R-HSA-1474244', 'R-HSA-6785807', 'R-HSA-3560782', 'R-HSA-381426', 'R-HSA-114608', 'R-HSA-9694614', 'R-HSA-198725', 'R-HSA-76002', 'R-HSA-191273', 'R-HSA-9925563', 'R-HSA-1630316', 'R-HSA-202733', 'R-HSA-3781865', 'R-HSA-166520', 'R-HSA-9820960', 'R-HSA-6783589', 'R-HSA-449147', 'R-HSA-112316', 'R-HSA-500792', 'R-HSA-373760', 'R-HSA-418990', 'R-HSA-9856532', 'R-HSA-140877', 'R-HSA-5576891', 'R-HSA-397014', 'R-HSA-5668914', 'R-HSA-416700', 'R-HSA-2162123', 'R-HSA-9855142', 'R-HSA-446728', 'R-HSA-9009391'], ['R-HSA-3000157', 'R-HSA-8874081', 'R-HSA-3000178', 'R-HSA-9925563', 'R-HSA-3000171', 'R-HSA-2173782', 'R-HSA-1474244', 'R-HSA-9734767', 'R-HSA-6806834', 'R-HSA-186797', 'R-HSA-6809371', 'R-HSA-69273', 'R-HSA-156711', 'R-HSA-6791312', 'R-HSA-3560782', 'R-HSA-419037'], ['R-HSA-1474244', 'R-HSA-2173782', 'R-HSA-9648895', 'R-HSA-9925563', 'R-HSA-9734767', 'R-HSA-176974', 'R-HSA-9671793']]
# -1 R-HSA-1474244
# -2 R-HSA-6785807
# -3 R-HSA-3560782
# -4 R-HSA-381426
# -5 R-HSA-114608
# -6 R-HSA-9694614
# -7 R-HSA-198725
# -8 R-HSA-76002
# -9 R-HSA-191273
# -10 R-HSA-9925563
# -11 R-HSA-3000157
# -12 R-HSA-8874081
# -13 R-HSA-3000178
# -10 R-HSA-9925563
# -14 R-HSA-3000171
# -15 R-HSA-2173782
# -1 R-HSA-1474244
# -16 R-HSA-9734767
# -17 R-HSA-6806834
# -18 R-HSA-186797
# -3 R-HSA-3560782
# -1 R-HSA-1474244
# -15 R-HSA-2173782
# -19 R-HSA-9648895
# -10 R-HSA-9925563
# -16 R-HSA-9734767
# -20 R-HSA-176974
# -21 R-HSA-9671793
# /var/folders/j2/645ctp717nv8rwbn2dsccyxh0000gn/T/ipykernel_3761/4212696362.py:50: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   matplotlib.pyplot.tight_layout()

# %%
list(range(len(contrasts)))
# Out:
# [0, 1, 2]

# %%
len(contrasts)
# Out:
# 3
