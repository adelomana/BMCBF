# %%
# read the table, plot the top 10 most significant and not redundant functions
# check the error of metabolism of lipids, and also in the other h1 analysis

# %%
import pandas, numpy

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(1/3), 9*(4/3)), 
                            'axes.labelsize':20
                           })
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
enrichments_file = '/Users/adrian/research/bmcbf/016.saudarkrokur/results/deseq2/clusterProfiler_enrichments.h2.tsv'

# %%
df = pandas.read_csv(enrichments_file, sep='\t')
df
# Out:
#               Cluster             ID  \
# 1         KO vs WT up  R-DME-1428517
# 2         KO vs WT up   R-DME-611105
# 3         KO vs WT up   R-DME-163210
# 4         KO vs WT up  R-DME-8949613
# 5         KO vs WT up  R-DME-1592230
# ..                ...            ...
# 243    h2low vs WT up  R-DME-9749641
# 244  h2low vs WT down  R-DME-3371497
# 245  h2low vs WT down  R-DME-6811442
# 246  h2low vs WT down  R-DME-9646399
# 247  h2low vs WT down  R-DME-6811436
#
#                                            Description GeneRatio   BgRatio  \
# 1    Aerobic respiration and respiratory electron t...    62/284  205/4708
# 2                       Respiratory electron transport    36/284  121/4708
# 3            Formation of ATP by chemiosmotic coupling    13/284   16/4708
# 4                                    Cristae formation    13/284   16/4708
# 5                             Mitochondrial biogenesis    14/284   21/4708
# ..                                                 ...       ...       ...
# 243                                       Aspirin ADME      4/77   43/4708
# 244  HSP90 chaperone cycle for steroid hormone rece...      5/23   51/4708
# 245     Intra-Golgi and retrograde Golgi-to-ER traffic      5/23  152/4708
# 246                                         Aggrephagy      3/23   37/4708
# 247    COPI-independent Golgi-to-ER retrograde traffic      3/23   42/4708
#
#      RichFactor  FoldEnrichment     zScore        pvalue      p.adjust  \
# 1      0.302439        5.013672  14.886465  5.672833e-29  1.906072e-26
# 2      0.297521        4.932138  11.101478  1.163092e-16  1.953994e-14
# 3      0.812500       13.469190  12.657355  5.114702e-14  4.296350e-12
# 4      0.812500       13.469190  12.657355  5.114702e-14  4.296350e-12
# 5      0.666667       11.051643  11.695612  4.914906e-13  3.302817e-11
# ..          ...             ...        ...           ...           ...
# 243    0.093023        5.687708   3.981521  5.035682e-03  4.431400e-02
# 244    0.098039       20.068201   9.592304  3.546826e-06  4.539937e-04
# 245    0.032895        6.733410   5.034127  6.899793e-04  3.030626e-02
# 246    0.081081       16.596945   6.672932  7.103030e-04  3.030626e-02
# 247    0.071429       14.621118   6.212212  1.032863e-03  3.305161e-02
#
#            qvalue                                             geneID  Count
# 1    1.534651e-26  35279/32007/50246/42759/41359/32989/44390/4540...     62
# 2    1.573234e-14  35279/50246/41359/32989/44390/45401/44228/4420...     36
# 3    3.459154e-12  42759/39143/43507/43693/41845/44046/37931/4229...     13
# 4    3.459154e-12  42759/39143/43507/43693/41845/44046/37931/4229...     13
# 5    2.659223e-11  42759/39143/43507/43693/41845/44046/37931/4229...     14
# ..            ...                                                ...    ...
# 243  3.710502e-02                            42336/37275/39392/34279      4
# 244  3.882841e-04               44920/48581/318231/26067074/26067075      5
# 245  2.591983e-02               37538/43671/318231/26067074/26067075      5
# 246  2.591983e-02                           318231/26067074/26067075      3
# 247  2.826782e-02                           318231/26067074/26067075      3
#
# [247 rows x 13 columns]

# %%
contrasts = []
for element in df['Cluster']:
    if element not in contrasts:
        contrasts.append(element)

print(contrasts)
# Out:
# ['KO vs WT up', 'KO vs WT down', 'h2high vs WT up', 'h2high vs WT down', 'h2high vs KO up', 'h2high vs KO down', 'h2low vs WT up', 'h2low vs WT down']

# %%
terms_to_use = []
top_ten_categories = []
for contrast in contrasts:
    
    print(contrast)
    sub = df[df['Cluster'] == contrast]
    all_observed_gene_lists = []
    contrast_terms = []
    top_ten = []
    
    for index, row in sub.iterrows():
        
        
        genes = row['geneID'].split('/')
        print('\t', row['ID'], row['Description'], len(genes))
        
        # checking the overlap
        overlap = False
        max_overlap = 0
        for element in all_observed_gene_lists:
            intersect = list(set(element) & set(genes))
            relative_intersect = len(intersect)/len(genes)
            #print('\t\t\t intersect is', len(intersect), relative_intersect)
            if max_overlap < relative_intersect:
                max_overlap = relative_intersect
            if relative_intersect > 0.9:
                overlap=True
            
        all_observed_gene_lists.append(genes)

        #print('\t', overlap)
        #print()
        if overlap == False:
            print('\t accepting', row['ID'], row['Description'], 'because overlap is', max_overlap)
            contrast_terms.append(row['ID'])
            if len(contrast_terms) <= 10:
                top_ten.append(row['ID'])
        else:
            print('\t rejecting', row['ID'], row['Description'], 'because overlap is', max_overlap)
        print()

    # end of contrast
    terms_to_use.append(contrast_terms)
    top_ten_categories.append(top_ten)
    print()
    #print(terms_to_use)
# Out:
# KO vs WT up
# 	 R-DME-1428517 Aerobic respiration and respiratory electron transport 62
# 	 accepting R-DME-1428517 Aerobic respiration and respiratory electron transport because overlap is 0
#
# 	 R-DME-611105 Respiratory electron transport 36
# 	 rejecting R-DME-611105 Respiratory electron transport because overlap is 1.0
#
# 	 R-DME-163210 Formation of ATP by chemiosmotic coupling 13
# 	 rejecting R-DME-163210 Formation of ATP by chemiosmotic coupling because overlap is 1.0
#
# 	 R-DME-8949613 Cristae formation 13
# 	 rejecting R-DME-8949613 Cristae formation because overlap is 1.0
#
# 	 R-DME-1592230 Mitochondrial biogenesis 14
# 	 rejecting R-DME-1592230 Mitochondrial biogenesis because overlap is 0.9285714285714286
#
# 	 R-DME-9837999 Mitochondrial protein degradation 24
# 	 accepting R-DME-9837999 Mitochondrial protein degradation because overlap is 0.7083333333333334
#
# 	 R-DME-70263 Gluconeogenesis 10
# 	 accepting R-DME-70263 Gluconeogenesis because overlap is 0
#
# 	 R-DME-5628897 TP53 Regulates Metabolic Genes 15
# 	 accepting R-DME-5628897 TP53 Regulates Metabolic Genes because overlap is 0.8
#
# 	 R-DME-1852241 Organelle biogenesis and maintenance 14
# 	 rejecting R-DME-1852241 Organelle biogenesis and maintenance because overlap is 1.0
#
# 	 R-DME-71387 Metabolism of carbohydrates and carbohydrate derivatives 30
# 	 accepting R-DME-71387 Metabolism of carbohydrates and carbohydrate derivatives because overlap is 0.3333333333333333
#
# 	 R-DME-8978868 Fatty acid metabolism 25
# 	 accepting R-DME-8978868 Fatty acid metabolism because overlap is 0.08
#
# 	 R-DME-9707564 Cytoprotection by HMOX1 12
# 	 rejecting R-DME-9707564 Cytoprotection by HMOX1 because overlap is 1.0
#
# 	 R-DME-71291 Metabolism of amino acids and derivatives 27
# 	 accepting R-DME-71291 Metabolism of amino acids and derivatives because overlap is 0.18518518518518517
#
# 	 R-DME-6799198 Complex I biogenesis 13
# 	 rejecting R-DME-6799198 Complex I biogenesis because overlap is 1.0
#
# 	 R-DME-70895 Branched-chain amino acid catabolism 7
# 	 rejecting R-DME-70895 Branched-chain amino acid catabolism because overlap is 1.0
#
# 	 R-DME-425407 SLC-mediated transmembrane transport 30
# 	 accepting R-DME-425407 SLC-mediated transmembrane transport because overlap is 0.2
#
# 	 R-DME-9865881 Complex III assembly 7
# 	 rejecting R-DME-9865881 Complex III assembly because overlap is 1.0
#
# 	 R-DME-428643 Organic anion transporters 11
# 	 rejecting R-DME-428643 Organic anion transporters because overlap is 1.0
#
# 	 R-DME-2022377 Metabolism of Angiotensinogen to Angiotensins 19
# 	 accepting R-DME-2022377 Metabolism of Angiotensinogen to Angiotensins because overlap is 0
#
# 	 R-DME-9864848 Complex IV assembly 10
# 	 rejecting R-DME-9864848 Complex IV assembly because overlap is 1.0
#
# 	 R-DME-211859 Biological oxidations 18
# 	 accepting R-DME-211859 Biological oxidations because overlap is 0.16666666666666666
#
# 	 R-DME-196757 Metabolism of folate and pterines 7
# 	 accepting R-DME-196757 Metabolism of folate and pterines because overlap is 0
#
# 	 R-DME-5653890 Lactose synthesis 6
# 	 rejecting R-DME-5653890 Lactose synthesis because overlap is 1.0
#
# 	 R-DME-2980736 Peptide hormone metabolism 19
# 	 rejecting R-DME-2980736 Peptide hormone metabolism because overlap is 1.0
#
# 	 R-DME-70326 Glucose metabolism 12
# 	 rejecting R-DME-70326 Glucose metabolism because overlap is 1.0
#
# 	 R-DME-75105 Fatty acyl-CoA biosynthesis 10
# 	 rejecting R-DME-75105 Fatty acyl-CoA biosynthesis because overlap is 1.0
#
# 	 R-DME-556833 Metabolism of lipids 47
# 	 accepting R-DME-556833 Metabolism of lipids because overlap is 0.5319148936170213
#
# 	 R-DME-425393 Transport of inorganic cations/anions and amino acids/oligopeptides 17
# 	 rejecting R-DME-425393 Transport of inorganic cations/anions and amino acids/oligopeptides because overlap is 1.0
#
# 	 R-DME-5652084 Fructose metabolism 5
# 	 rejecting R-DME-5652084 Fructose metabolism because overlap is 1.0
#
# 	 R-DME-397014 Muscle contraction 14
# 	 accepting R-DME-397014 Muscle contraction because overlap is 0.5
#
# 	 R-DME-5362517 Signaling by Retinoic Acid 7
# 	 accepting R-DME-5362517 Signaling by Retinoic Acid because overlap is 0.42857142857142855
#
# 	 R-DME-2162123 Synthesis of Prostaglandins (PG) and Thromboxanes (TX) 5
# 	 rejecting R-DME-2162123 Synthesis of Prostaglandins (PG) and Thromboxanes (TX) because overlap is 1.0
#
# 	 R-DME-211945 Phase I - Functionalization of compounds 10
# 	 rejecting R-DME-211945 Phase I - Functionalization of compounds because overlap is 1.0
#
# 	 R-DME-70171 Glycolysis 10
# 	 rejecting R-DME-70171 Glycolysis because overlap is 1.0
#
# 	 R-DME-9748784 Drug ADME 18
# 	 accepting R-DME-9748784 Drug ADME because overlap is 0.5
#
# 	 R-DME-5661270 Formation of xylulose-5-phosphate 4
# 	 rejecting R-DME-5661270 Formation of xylulose-5-phosphate because overlap is 1.0
#
# 	 R-DME-196849 Metabolism of water-soluble vitamins and cofactors 11
# 	 accepting R-DME-196849 Metabolism of water-soluble vitamins and cofactors because overlap is 0.6363636363636364
#
# 	 R-DME-196854 Metabolism of vitamins and cofactors 16
# 	 accepting R-DME-196854 Metabolism of vitamins and cofactors because overlap is 0.6875
#
# 	 R-DME-5578768 Physiological factors 7
# 	 rejecting R-DME-5578768 Physiological factors because overlap is 1.0
#
# 	 R-DME-70268 Pyruvate metabolism 8
# 	 rejecting R-DME-70268 Pyruvate metabolism because overlap is 1.0
#
# 	 R-DME-112311 Neurotransmitter clearance 7
# 	 accepting R-DME-112311 Neurotransmitter clearance because overlap is 0.8571428571428571
#
# 	 R-DME-9711123 Cellular response to chemical stress 14
# 	 rejecting R-DME-9711123 Cellular response to chemical stress because overlap is 1.0
#
#
# KO vs WT down
# 	 R-DME-3371497 HSP90 chaperone cycle for steroid hormone receptors (SHR) in the presence of ligand 7
# 	 accepting R-DME-3371497 HSP90 chaperone cycle for steroid hormone receptors (SHR) in the presence of ligand because overlap is 0
#
# 	 R-DME-6811436 COPI-independent Golgi-to-ER retrograde traffic 6
# 	 rejecting R-DME-6811436 COPI-independent Golgi-to-ER retrograde traffic because overlap is 1.0
#
# 	 R-DME-425407 SLC-mediated transmembrane transport 11
# 	 accepting R-DME-425407 SLC-mediated transmembrane transport because overlap is 0
#
# 	 R-DME-6811442 Intra-Golgi and retrograde Golgi-to-ER traffic 9
# 	 accepting R-DME-6811442 Intra-Golgi and retrograde Golgi-to-ER traffic because overlap is 0.6666666666666666
#
# 	 R-DME-9663891 Selective autophagy 6
# 	 accepting R-DME-9663891 Selective autophagy because overlap is 0.8333333333333334
#
# 	 R-DME-9646399 Aggrephagy 5
# 	 rejecting R-DME-9646399 Aggrephagy because overlap is 1.0
#
# 	 R-DME-8856688 Golgi-to-ER retrograde transport 7
# 	 rejecting R-DME-8856688 Golgi-to-ER retrograde transport because overlap is 1.0
#
# 	 R-DME-1632852 Macroautophagy 7
# 	 accepting R-DME-1632852 Macroautophagy because overlap is 0.8571428571428571
#
# 	 R-DME-9612973 Autophagy 7
# 	 rejecting R-DME-9612973 Autophagy because overlap is 1.0
#
# 	 R-DME-6807878 COPI-mediated anterograde transport 6
# 	 rejecting R-DME-6807878 COPI-mediated anterograde transport because overlap is 1.0
#
# 	 R-DME-432040 Vasopressin regulates renal water homeostasis via Aquaporins 3
# 	 accepting R-DME-432040 Vasopressin regulates renal water homeostasis via Aquaporins because overlap is 0
#
# 	 R-DME-199977 ER to Golgi Anterograde Transport 7
# 	 accepting R-DME-199977 ER to Golgi Anterograde Transport because overlap is 0.8571428571428571
#
# 	 R-DME-445717 Aquaporin-mediated transport 3
# 	 rejecting R-DME-445717 Aquaporin-mediated transport because overlap is 1.0
#
# 	 R-DME-425366 Transport of bile salts and organic acids, metal ions and amine compounds 5
# 	 rejecting R-DME-425366 Transport of bile salts and organic acids, metal ions and amine compounds because overlap is 1.0
#
# 	 R-DME-948021 Transport to the Golgi and subsequent modification 7
# 	 rejecting R-DME-948021 Transport to the Golgi and subsequent modification because overlap is 1.0
#
# 	 R-DME-199991 Membrane Trafficking 11
# 	 accepting R-DME-199991 Membrane Trafficking because overlap is 0.8181818181818182
#
# 	 R-DME-5653656 Vesicle-mediated transport 11
# 	 rejecting R-DME-5653656 Vesicle-mediated transport because overlap is 1.0
#
# 	 R-DME-9793528 Ciprofloxacin ADME 3
# 	 accepting R-DME-9793528 Ciprofloxacin ADME because overlap is 0.6666666666666666
#
# 	 R-DME-8953897 Cellular responses to stimuli 11
# 	 accepting R-DME-8953897 Cellular responses to stimuli because overlap is 0.6363636363636364
#
#
# h2high vs WT up
# 	 R-DME-1428517 Aerobic respiration and respiratory electron transport 67
# 	 accepting R-DME-1428517 Aerobic respiration and respiratory electron transport because overlap is 0
#
# 	 R-DME-611105 Respiratory electron transport 44
# 	 rejecting R-DME-611105 Respiratory electron transport because overlap is 1.0
#
# 	 R-DME-6799198 Complex I biogenesis 20
# 	 rejecting R-DME-6799198 Complex I biogenesis because overlap is 1.0
#
# 	 R-DME-163210 Formation of ATP by chemiosmotic coupling 11
# 	 rejecting R-DME-163210 Formation of ATP by chemiosmotic coupling because overlap is 1.0
#
# 	 R-DME-8949613 Cristae formation 11
# 	 rejecting R-DME-8949613 Cristae formation because overlap is 1.0
#
# 	 R-DME-70895 Branched-chain amino acid catabolism 10
# 	 accepting R-DME-70895 Branched-chain amino acid catabolism because overlap is 0
#
# 	 R-DME-1592230 Mitochondrial biogenesis 11
# 	 rejecting R-DME-1592230 Mitochondrial biogenesis because overlap is 1.0
#
# 	 R-DME-9837999 Mitochondrial protein degradation 21
# 	 accepting R-DME-9837999 Mitochondrial protein degradation because overlap is 0.5714285714285714
#
# 	 R-DME-211859 Biological oxidations 25
# 	 accepting R-DME-211859 Biological oxidations because overlap is 0.04
#
# 	 R-DME-71291 Metabolism of amino acids and derivatives 32
# 	 accepting R-DME-71291 Metabolism of amino acids and derivatives because overlap is 0.3125
#
# 	 R-DME-428643 Organic anion transporters 14
# 	 accepting R-DME-428643 Organic anion transporters because overlap is 0.42857142857142855
#
# 	 R-DME-8978868 Fatty acid metabolism 28
# 	 accepting R-DME-8978868 Fatty acid metabolism because overlap is 0.17857142857142858
#
# 	 R-DME-70263 Gluconeogenesis 9
# 	 accepting R-DME-70263 Gluconeogenesis because overlap is 0
#
# 	 R-DME-196854 Metabolism of vitamins and cofactors 25
# 	 accepting R-DME-196854 Metabolism of vitamins and cofactors because overlap is 0.24
#
# 	 R-DME-556833 Metabolism of lipids 63
# 	 accepting R-DME-556833 Metabolism of lipids because overlap is 0.4444444444444444
#
# 	 R-DME-2022377 Metabolism of Angiotensinogen to Angiotensins 23
# 	 accepting R-DME-2022377 Metabolism of Angiotensinogen to Angiotensins because overlap is 0.13043478260869565
#
# 	 R-DME-5652084 Fructose metabolism 7
# 	 accepting R-DME-5652084 Fructose metabolism because overlap is 0.7142857142857143
#
# 	 R-DME-1852241 Organelle biogenesis and maintenance 13
# 	 accepting R-DME-1852241 Organelle biogenesis and maintenance because overlap is 0.8461538461538461
#
# 	 R-DME-2980736 Peptide hormone metabolism 24
# 	 rejecting R-DME-2980736 Peptide hormone metabolism because overlap is 0.9583333333333334
#
# 	 R-DME-9757110 Prednisone ADME 16
# 	 accepting R-DME-9757110 Prednisone ADME because overlap is 0.375
#
# 	 R-DME-2162123 Synthesis of Prostaglandins (PG) and Thromboxanes (TX) 7
# 	 rejecting R-DME-2162123 Synthesis of Prostaglandins (PG) and Thromboxanes (TX) because overlap is 1.0
#
# 	 R-DME-9748784 Drug ADME 25
# 	 accepting R-DME-9748784 Drug ADME because overlap is 0.64
#
# 	 R-DME-5628897 TP53 Regulates Metabolic Genes 13
# 	 accepting R-DME-5628897 TP53 Regulates Metabolic Genes because overlap is 0.8461538461538461
#
# 	 R-DME-9753281 Paracetamol ADME 13
# 	 rejecting R-DME-9753281 Paracetamol ADME because overlap is 1.0
#
# 	 R-DME-5661270 Formation of xylulose-5-phosphate 6
# 	 accepting R-DME-5661270 Formation of xylulose-5-phosphate because overlap is 0.8333333333333334
#
# 	 R-DME-9857492 Protein lipoylation 6
# 	 accepting R-DME-9857492 Protein lipoylation because overlap is 0.3333333333333333
#
# 	 R-DME-9707564 Cytoprotection by HMOX1 11
# 	 rejecting R-DME-9707564 Cytoprotection by HMOX1 because overlap is 1.0
#
# 	 R-DME-425407 SLC-mediated transmembrane transport 33
# 	 accepting R-DME-425407 SLC-mediated transmembrane transport because overlap is 0.42424242424242425
#
# 	 R-DME-9865881 Complex III assembly 7
# 	 rejecting R-DME-9865881 Complex III assembly because overlap is 1.0
#
# 	 R-DME-211945 Phase I - Functionalization of compounds 13
# 	 rejecting R-DME-211945 Phase I - Functionalization of compounds because overlap is 1.0
#
# 	 R-DME-193144 Estrogen biosynthesis 10
# 	 rejecting R-DME-193144 Estrogen biosynthesis because overlap is 1.0
#
# 	 R-DME-9864848 Complex IV assembly 10
# 	 rejecting R-DME-9864848 Complex IV assembly because overlap is 1.0
#
# 	 R-DME-75105 Fatty acyl-CoA biosynthesis 11
# 	 rejecting R-DME-75105 Fatty acyl-CoA biosynthesis because overlap is 1.0
#
# 	 R-DME-156590 Glutathione conjugation 9
# 	 rejecting R-DME-156590 Glutathione conjugation because overlap is 1.0
#
# 	 R-DME-425393 Transport of inorganic cations/anions and amino acids/oligopeptides 20
# 	 rejecting R-DME-425393 Transport of inorganic cations/anions and amino acids/oligopeptides because overlap is 1.0
#
# 	 R-DME-6806667 Metabolism of fat-soluble vitamins 9
# 	 rejecting R-DME-6806667 Metabolism of fat-soluble vitamins because overlap is 1.0
#
# 	 R-DME-5362517 Signaling by Retinoic Acid 8
# 	 accepting R-DME-5362517 Signaling by Retinoic Acid because overlap is 0.625
#
# 	 R-DME-983170 Antigen Presentation: Folding, assembly and peptide loading of class I MHC 7
# 	 accepting R-DME-983170 Antigen Presentation: Folding, assembly and peptide loading of class I MHC because overlap is 0.8571428571428571
#
# 	 R-DME-156580 Phase II - Conjugation of compounds 11
# 	 rejecting R-DME-156580 Phase II - Conjugation of compounds because overlap is 1.0
#
# 	 R-DME-71387 Metabolism of carbohydrates and carbohydrate derivatives 27
# 	 accepting R-DME-71387 Metabolism of carbohydrates and carbohydrate derivatives because overlap is 0.3333333333333333
#
# 	 R-DME-2142753 Arachidonate metabolism 8
# 	 rejecting R-DME-2142753 Arachidonate metabolism because overlap is 1.0
#
# 	 R-DME-168643 Nucleotide-binding domain, leucine rich repeat containing receptor (NLR) signaling pathways 6
# 	 accepting R-DME-168643 Nucleotide-binding domain, leucine rich repeat containing receptor (NLR) signaling pathways because overlap is 0.16666666666666666
#
# 	 R-DME-5365859 RA biosynthesis pathway 6
# 	 rejecting R-DME-5365859 RA biosynthesis pathway because overlap is 1.0
#
# 	 R-DME-70221 Glycogen breakdown (glycogenolysis) 5
# 	 rejecting R-DME-70221 Glycogen breakdown (glycogenolysis) because overlap is 1.0
#
# 	 R-DME-8963743 Digestion and absorption 11
# 	 accepting R-DME-8963743 Digestion and absorption because overlap is 0.7272727272727273
#
# 	 R-DME-196071 Metabolism of steroid hormones 12
# 	 rejecting R-DME-196071 Metabolism of steroid hormones because overlap is 1.0
#
# 	 R-DME-427601 Multifunctional anion exchangers 5
# 	 rejecting R-DME-427601 Multifunctional anion exchangers because overlap is 1.0
#
# 	 R-DME-5653890 Lactose synthesis 5
# 	 rejecting R-DME-5653890 Lactose synthesis because overlap is 1.0
#
# 	 R-DME-622312 Inflammasomes 5
# 	 rejecting R-DME-622312 Inflammasomes because overlap is 1.0
#
# 	 R-DME-844456 The NLRP3 inflammasome 5
# 	 rejecting R-DME-844456 The NLRP3 inflammasome because overlap is 1.0
#
# 	 R-DME-189200 Cellular hexose transport 6
# 	 rejecting R-DME-189200 Cellular hexose transport because overlap is 1.0
#
# 	 R-DME-8935690 Digestion 10
# 	 rejecting R-DME-8935690 Digestion because overlap is 1.0
#
# 	 R-DME-209968 Thyroxine biosynthesis 5
# 	 rejecting R-DME-209968 Thyroxine biosynthesis because overlap is 1.0
#
# 	 R-DME-196849 Metabolism of water-soluble vitamins and cofactors 12
# 	 rejecting R-DME-196849 Metabolism of water-soluble vitamins and cofactors because overlap is 1.0
#
# 	 R-DME-15869 Metabolism of nucleotides 10
# 	 accepting R-DME-15869 Metabolism of nucleotides because overlap is 0.1
#
# 	 R-DME-193775 Synthesis of bile acids and bile salts via 24-hydroxycholesterol 4
# 	 rejecting R-DME-193775 Synthesis of bile acids and bile salts via 24-hydroxycholesterol because overlap is 1.0
#
# 	 R-DME-975634 Retinoid metabolism and transport 4
# 	 rejecting R-DME-975634 Retinoid metabolism and transport because overlap is 1.0
#
# 	 R-DME-193368 Synthesis of bile acids and bile salts via 7alpha-hydroxycholesterol 5
# 	 rejecting R-DME-193368 Synthesis of bile acids and bile salts via 7alpha-hydroxycholesterol because overlap is 1.0
#
#
# h2high vs WT down
# 	 R-DME-8956320 Nucleotide biosynthesis 6
# 	 accepting R-DME-8956320 Nucleotide biosynthesis because overlap is 0
#
# 	 R-DME-352230 Amino acid transport across the plasma membrane 10
# 	 accepting R-DME-352230 Amino acid transport across the plasma membrane because overlap is 0
#
# 	 R-DME-425407 SLC-mediated transmembrane transport 21
# 	 accepting R-DME-425407 SLC-mediated transmembrane transport because overlap is 0.47619047619047616
#
# 	 R-DME-425393 Transport of inorganic cations/anions and amino acids/oligopeptides 14
# 	 rejecting R-DME-425393 Transport of inorganic cations/anions and amino acids/oligopeptides because overlap is 1.0
#
# 	 R-DME-6798695 Neutrophil degranulation 31
# 	 accepting R-DME-6798695 Neutrophil degranulation because overlap is 0.0967741935483871
#
# 	 R-DME-382556 ABC-family proteins mediated transport 11
# 	 accepting R-DME-382556 ABC-family proteins mediated transport because overlap is 0.36363636363636365
#
# 	 R-DME-9748784 Drug ADME 14
# 	 accepting R-DME-9748784 Drug ADME because overlap is 0.35714285714285715
#
# 	 R-DME-15869 Metabolism of nucleotides 8
# 	 accepting R-DME-15869 Metabolism of nucleotides because overlap is 0.75
#
# 	 R-DME-1474244 Extracellular matrix organization 9
# 	 accepting R-DME-1474244 Extracellular matrix organization because overlap is 0.3333333333333333
#
# 	 R-DME-9840310 Glycosphingolipid catabolism 4
# 	 accepting R-DME-9840310 Glycosphingolipid catabolism because overlap is 0.5
#
#
# h2high vs KO up
# 	 R-DME-8866654 E3 ubiquitin ligases ubiquitinate target proteins 23
# 	 accepting R-DME-8866654 E3 ubiquitin ligases ubiquitinate target proteins because overlap is 0
#
# 	 R-DME-8852135 Protein ubiquitination 24
# 	 rejecting R-DME-8852135 Protein ubiquitination because overlap is 0.9583333333333334
#
# 	 R-DME-2299718 Condensation of Prophase Chromosomes 23
# 	 rejecting R-DME-2299718 Condensation of Prophase Chromosomes because overlap is 1.0
#
# 	 R-DME-5693565 Recruitment and ATM-mediated phosphorylation of repair and signaling proteins at DNA double strand breaks 24
# 	 rejecting R-DME-5693565 Recruitment and ATM-mediated phosphorylation of repair and signaling proteins at DNA double strand breaks because overlap is 0.9583333333333334
#
# 	 R-DME-5693606 DNA Double Strand Break Response 24
# 	 rejecting R-DME-5693606 DNA Double Strand Break Response because overlap is 1.0
#
# 	 R-DME-68616 Assembly of the ORC complex at the origin of replication 24
# 	 rejecting R-DME-68616 Assembly of the ORC complex at the origin of replication because overlap is 0.9583333333333334
#
# 	 R-DME-427413 NoRC negatively regulates rRNA expression 23
# 	 rejecting R-DME-427413 NoRC negatively regulates rRNA expression because overlap is 1.0
#
# 	 R-DME-427359 SIRT1 negatively regulates rRNA expression 23
# 	 rejecting R-DME-427359 SIRT1 negatively regulates rRNA expression because overlap is 1.0
#
# 	 R-DME-5250941 Negative epigenetic regulation of rRNA expression 23
# 	 rejecting R-DME-5250941 Negative epigenetic regulation of rRNA expression because overlap is 1.0
#
# 	 R-DME-212300 PRC2 methylates histones and DNA 23
# 	 rejecting R-DME-212300 PRC2 methylates histones and DNA because overlap is 1.0
#
# 	 R-DME-68867 Assembly of the pre-replicative complex 24
# 	 rejecting R-DME-68867 Assembly of the pre-replicative complex because overlap is 1.0
#
# 	 R-DME-5625886 Activated PKN1 stimulates transcription of AR (androgen receptor) regulated genes KLK2 and KLK3 23
# 	 rejecting R-DME-5625886 Activated PKN1 stimulates transcription of AR (androgen receptor) regulated genes KLK2 and KLK3 because overlap is 1.0
#
# 	 R-DME-5625740 RHO GTPases activate PKNs 24
# 	 rejecting R-DME-5625740 RHO GTPases activate PKNs because overlap is 0.9583333333333334
#
# 	 R-DME-5689880 Ub-specific processing proteases 27
# 	 accepting R-DME-5689880 Ub-specific processing proteases because overlap is 0.8888888888888888
#
# 	 R-DME-5693532 DNA Double-Strand Break Repair 24
# 	 rejecting R-DME-5693532 DNA Double-Strand Break Repair because overlap is 1.0
#
# 	 R-DME-201722 Formation of the beta-catenin:TCF transactivating complex 23
# 	 rejecting R-DME-201722 Formation of the beta-catenin:TCF transactivating complex because overlap is 1.0
#
# 	 R-DME-3214847 HATs acetylate histones 23
# 	 rejecting R-DME-3214847 HATs acetylate histones because overlap is 1.0
#
# 	 R-DME-69002 DNA Replication Pre-Initiation 24
# 	 rejecting R-DME-69002 DNA Replication Pre-Initiation because overlap is 1.0
#
# 	 R-DME-3214815 HDACs deacetylate histones 23
# 	 rejecting R-DME-3214815 HDACs deacetylate histones because overlap is 1.0
#
# 	 R-DME-2559580 Oxidative Stress Induced Senescence 23
# 	 rejecting R-DME-2559580 Oxidative Stress Induced Senescence because overlap is 1.0
#
# 	 R-DME-8936459 RUNX1 regulates genes involved in megakaryocyte differentiation and platelet function 23
# 	 rejecting R-DME-8936459 RUNX1 regulates genes involved in megakaryocyte differentiation and platelet function because overlap is 1.0
#
# 	 R-DME-68875 Mitotic Prophase 23
# 	 rejecting R-DME-68875 Mitotic Prophase because overlap is 1.0
#
# 	 R-DME-73772 RNA Polymerase I Promoter Escape 23
# 	 rejecting R-DME-73772 RNA Polymerase I Promoter Escape because overlap is 1.0
#
# 	 R-DME-73854 RNA Polymerase I Promoter Clearance 23
# 	 rejecting R-DME-73854 RNA Polymerase I Promoter Clearance because overlap is 1.0
#
# 	 R-DME-73864 RNA Polymerase I Transcription 23
# 	 rejecting R-DME-73864 RNA Polymerase I Transcription because overlap is 1.0
#
# 	 R-DME-9842860 Regulation of endogenous retroelements 23
# 	 rejecting R-DME-9842860 Regulation of endogenous retroelements because overlap is 1.0
#
# 	 R-DME-9843940 Regulation of endogenous retroelements by KRAB-ZFP proteins 23
# 	 rejecting R-DME-9843940 Regulation of endogenous retroelements by KRAB-ZFP proteins because overlap is 1.0
#
# 	 R-DME-2559582 Senescence-Associated Secretory Phenotype (SASP) 23
# 	 rejecting R-DME-2559582 Senescence-Associated Secretory Phenotype (SASP) because overlap is 1.0
#
# 	 R-DME-9818564 Epigenetic regulation of gene expression by MLL3 and MLL4 complexes 23
# 	 rejecting R-DME-9818564 Epigenetic regulation of gene expression by MLL3 and MLL4 complexes because overlap is 1.0
#
# 	 R-DME-9841922 MLL4 and MLL3 complexes regulate expression of PPARG target genes in adipogenesis and hepatic steatosis 23
# 	 rejecting R-DME-9841922 MLL4 and MLL3 complexes regulate expression of PPARG target genes in adipogenesis and hepatic steatosis because overlap is 1.0
#
# 	 R-DME-9851695 Epigenetic regulation of adipogenesis genes by MLL3 and MLL4 complexes 23
# 	 rejecting R-DME-9851695 Epigenetic regulation of adipogenesis genes by MLL3 and MLL4 complexes because overlap is 1.0
#
# 	 R-DME-211000 Gene Silencing by RNA 24
# 	 rejecting R-DME-211000 Gene Silencing by RNA because overlap is 0.9583333333333334
#
# 	 R-DME-5688426 Deubiquitination 27
# 	 rejecting R-DME-5688426 Deubiquitination because overlap is 1.0
#
# 	 R-DME-5578749 Transcriptional regulation by small RNAs 23
# 	 rejecting R-DME-5578749 Transcriptional regulation by small RNAs because overlap is 1.0
#
# 	 R-DME-195258 RHO GTPase Effectors 25
# 	 rejecting R-DME-195258 RHO GTPase Effectors because overlap is 0.96
#
# 	 R-DME-2559583 Cellular Senescence 24
# 	 rejecting R-DME-2559583 Cellular Senescence because overlap is 1.0
#
# 	 R-DME-9917777 Epigenetic regulation by WDR5-containing histone modifying complexes 23
# 	 rejecting R-DME-9917777 Epigenetic regulation by WDR5-containing histone modifying complexes because overlap is 1.0
#
# 	 R-DME-9018519 Estrogen-dependent gene expression 23
# 	 rejecting R-DME-9018519 Estrogen-dependent gene expression because overlap is 1.0
#
# 	 R-DME-73894 DNA Repair 27
# 	 accepting R-DME-73894 DNA Repair because overlap is 0.8888888888888888
#
# 	 R-DME-3247509 Chromatin modifying enzymes 23
# 	 rejecting R-DME-3247509 Chromatin modifying enzymes because overlap is 1.0
#
# 	 R-DME-8953897 Cellular responses to stimuli 39
# 	 accepting R-DME-8953897 Cellular responses to stimuli because overlap is 0.6153846153846154
#
# 	 R-DME-201681 TCF dependent signaling in response to WNT 24
# 	 rejecting R-DME-201681 TCF dependent signaling in response to WNT because overlap is 1.0
#
# 	 R-DME-4839726 Chromatin organization 23
# 	 rejecting R-DME-4839726 Chromatin organization because overlap is 1.0
#
# 	 R-DME-2262752 Cellular responses to stress 36
# 	 rejecting R-DME-2262752 Cellular responses to stress because overlap is 1.0
#
# 	 R-DME-212165 Epigenetic regulation of gene expression 23
# 	 rejecting R-DME-212165 Epigenetic regulation of gene expression because overlap is 1.0
#
# 	 R-DME-8939211 ESR-mediated signaling 23
# 	 rejecting R-DME-8939211 ESR-mediated signaling because overlap is 1.0
#
# 	 R-DME-69306 DNA Replication 24
# 	 rejecting R-DME-69306 DNA Replication because overlap is 1.0
#
# 	 R-DME-9006931 Signaling by Nuclear Receptors 25
# 	 rejecting R-DME-9006931 Signaling by Nuclear Receptors because overlap is 0.92
#
# 	 R-DME-9663891 Selective autophagy 12
# 	 accepting R-DME-9663891 Selective autophagy because overlap is 0.5
#
# 	 R-DME-68886 M Phase 23
# 	 rejecting R-DME-68886 M Phase because overlap is 1.0
#
# 	 R-DME-195721 Signaling by WNT 24
# 	 rejecting R-DME-195721 Signaling by WNT because overlap is 1.0
#
# 	 R-DME-8878171 Transcriptional regulation by RUNX1 23
# 	 rejecting R-DME-8878171 Transcriptional regulation by RUNX1 because overlap is 1.0
#
# 	 R-DME-9646399 Aggrephagy 9
# 	 rejecting R-DME-9646399 Aggrephagy because overlap is 1.0
#
# 	 R-DME-3371497 HSP90 chaperone cycle for steroid hormone receptors (SHR) in the presence of ligand 10
# 	 rejecting R-DME-3371497 HSP90 chaperone cycle for steroid hormone receptors (SHR) in the presence of ligand because overlap is 1.0
#
# 	 R-DME-70326 Glucose metabolism 11
# 	 accepting R-DME-70326 Glucose metabolism because overlap is 0
#
# 	 R-DME-1632852 Macroautophagy 14
# 	 accepting R-DME-1632852 Macroautophagy because overlap is 0.8571428571428571
#
# 	 R-DME-9612973 Autophagy 14
# 	 rejecting R-DME-9612973 Autophagy because overlap is 1.0
#
# 	 R-DME-70263 Gluconeogenesis 6
# 	 rejecting R-DME-70263 Gluconeogenesis because overlap is 1.0
#
# 	 R-DME-9716542 Signaling by Rho GTPases, Miro GTPases and RHOBTB3 28
# 	 accepting R-DME-9716542 Signaling by Rho GTPases, Miro GTPases and RHOBTB3 because overlap is 0.8928571428571429
#
# 	 R-DME-69278 Cell Cycle, Mitotic 26
# 	 rejecting R-DME-69278 Cell Cycle, Mitotic because overlap is 0.9230769230769231
#
# 	 R-DME-194315 Signaling by Rho GTPases 27
# 	 rejecting R-DME-194315 Signaling by Rho GTPases because overlap is 1.0
#
# 	 R-DME-1640170 Cell Cycle 27
# 	 rejecting R-DME-1640170 Cell Cycle because overlap is 0.9629629629629629
#
# 	 R-DME-6811436 COPI-independent Golgi-to-ER retrograde traffic 8
# 	 rejecting R-DME-6811436 COPI-independent Golgi-to-ER retrograde traffic because overlap is 1.0
#
# 	 R-DME-70171 Glycolysis 9
# 	 rejecting R-DME-70171 Glycolysis because overlap is 1.0
#
# 	 R-DME-70268 Pyruvate metabolism 7
# 	 accepting R-DME-70268 Pyruvate metabolism because overlap is 0.42857142857142855
#
# 	 R-DME-432040 Vasopressin regulates renal water homeostasis via Aquaporins 4
# 	 accepting R-DME-432040 Vasopressin regulates renal water homeostasis via Aquaporins because overlap is 0.5
#
# 	 R-DME-71387 Metabolism of carbohydrates and carbohydrate derivatives 16
# 	 accepting R-DME-71387 Metabolism of carbohydrates and carbohydrate derivatives because overlap is 0.6875
#
# 	 R-DME-8856688 Golgi-to-ER retrograde transport 10
# 	 accepting R-DME-8856688 Golgi-to-ER retrograde transport because overlap is 0.8
#
# 	 R-DME-445717 Aquaporin-mediated transport 4
# 	 rejecting R-DME-445717 Aquaporin-mediated transport because overlap is 1.0
#
# 	 R-DME-2980736 Peptide hormone metabolism 12
# 	 accepting R-DME-2980736 Peptide hormone metabolism because overlap is 0
#
# 	 R-DME-2022377 Metabolism of Angiotensinogen to Angiotensins 11
# 	 rejecting R-DME-2022377 Metabolism of Angiotensinogen to Angiotensins because overlap is 1.0
#
# 	 R-DME-112043 PLC beta mediated events 5
# 	 accepting R-DME-112043 PLC beta mediated events because overlap is 0.6
#
# 	 R-DME-111931 PKA-mediated phosphorylation of CREB 4
# 	 rejecting R-DME-111931 PKA-mediated phosphorylation of CREB because overlap is 1.0
#
# 	 R-DME-163615 PKA activation 4
# 	 rejecting R-DME-163615 PKA activation because overlap is 1.0
#
# 	 R-DME-112040 G-protein mediated events 5
# 	 rejecting R-DME-112040 G-protein mediated events because overlap is 1.0
#
# 	 R-DME-6807878 COPI-mediated anterograde transport 8
# 	 rejecting R-DME-6807878 COPI-mediated anterograde transport because overlap is 1.0
#
# 	 R-DME-425407 SLC-mediated transmembrane transport 16
# 	 accepting R-DME-425407 SLC-mediated transmembrane transport because overlap is 0
#
# 	 R-DME-9857492 Protein lipoylation 3
# 	 accepting R-DME-9857492 Protein lipoylation because overlap is 0
#
#
# h2high vs KO down
# 	 R-DME-425407 SLC-mediated transmembrane transport 15
# 	 accepting R-DME-425407 SLC-mediated transmembrane transport because overlap is 0
#
# 	 R-DME-8935690 Digestion 7
# 	 accepting R-DME-8935690 Digestion because overlap is 0
#
# 	 R-DME-8963743 Digestion and absorption 7
# 	 rejecting R-DME-8963743 Digestion and absorption because overlap is 1.0
#
# 	 R-DME-8956320 Nucleotide biosynthesis 4
# 	 accepting R-DME-8956320 Nucleotide biosynthesis because overlap is 0
#
# 	 R-DME-425393 Transport of inorganic cations/anions and amino acids/oligopeptides 9
# 	 rejecting R-DME-425393 Transport of inorganic cations/anions and amino acids/oligopeptides because overlap is 1.0
#
# 	 R-DME-556833 Metabolism of lipids 19
# 	 accepting R-DME-556833 Metabolism of lipids because overlap is 0.3157894736842105
#
# 	 R-DME-5578768 Physiological factors 5
# 	 accepting R-DME-5578768 Physiological factors because overlap is 0
#
# 	 R-DME-6798695 Neutrophil degranulation 17
# 	 accepting R-DME-6798695 Neutrophil degranulation because overlap is 0.29411764705882354
#
# 	 R-DME-2022377 Metabolism of Angiotensinogen to Angiotensins 8
# 	 accepting R-DME-2022377 Metabolism of Angiotensinogen to Angiotensins because overlap is 0.875
#
# 	 R-DME-2980736 Peptide hormone metabolism 8
# 	 rejecting R-DME-2980736 Peptide hormone metabolism because overlap is 1.0
#
# 	 R-DME-9840310 Glycosphingolipid catabolism 3
# 	 rejecting R-DME-9840310 Glycosphingolipid catabolism because overlap is 1.0
#
# 	 R-DME-352230 Amino acid transport across the plasma membrane 5
# 	 rejecting R-DME-352230 Amino acid transport across the plasma membrane because overlap is 1.0
#
# 	 R-DME-15869 Metabolism of nucleotides 5
# 	 accepting R-DME-15869 Metabolism of nucleotides because overlap is 0.8
#
# 	 R-DME-1483166 Synthesis of PA 4
# 	 rejecting R-DME-1483166 Synthesis of PA because overlap is 1.0
#
# 	 R-DME-5576891 Cardiac conduction 5
# 	 rejecting R-DME-5576891 Cardiac conduction because overlap is 1.0
#
# 	 R-DME-6811438 Intra-Golgi traffic 4
# 	 rejecting R-DME-6811438 Intra-Golgi traffic because overlap is 1.0
#
#
# h2low vs WT up
# 	 R-DME-9748784 Drug ADME 12
# 	 accepting R-DME-9748784 Drug ADME because overlap is 0
#
# 	 R-DME-5653890 Lactose synthesis 5
# 	 accepting R-DME-5653890 Lactose synthesis because overlap is 0
#
# 	 R-DME-9753281 Paracetamol ADME 7
# 	 rejecting R-DME-9753281 Paracetamol ADME because overlap is 1.0
#
# 	 R-DME-3371497 HSP90 chaperone cycle for steroid hormone receptors (SHR) in the presence of ligand 7
# 	 accepting R-DME-3371497 HSP90 chaperone cycle for steroid hormone receptors (SHR) in the presence of ligand because overlap is 0
#
# 	 R-DME-211945 Phase I - Functionalization of compounds 6
# 	 accepting R-DME-211945 Phase I - Functionalization of compounds because overlap is 0.3333333333333333
#
# 	 R-DME-425407 SLC-mediated transmembrane transport 12
# 	 accepting R-DME-425407 SLC-mediated transmembrane transport because overlap is 0.25
#
# 	 R-DME-211859 Biological oxidations 8
# 	 accepting R-DME-211859 Biological oxidations because overlap is 0.75
#
# 	 R-DME-425393 Transport of inorganic cations/anions and amino acids/oligopeptides 8
# 	 rejecting R-DME-425393 Transport of inorganic cations/anions and amino acids/oligopeptides because overlap is 1.0
#
# 	 R-DME-428643 Organic anion transporters 5
# 	 rejecting R-DME-428643 Organic anion transporters because overlap is 1.0
#
# 	 R-DME-211976 Endogenous sterols 4
# 	 rejecting R-DME-211976 Endogenous sterols because overlap is 1.0
#
# 	 R-DME-211897 Cytochrome P450 - arranged by substrate type 4
# 	 rejecting R-DME-211897 Cytochrome P450 - arranged by substrate type because overlap is 1.0
#
# 	 R-DME-622312 Inflammasomes 3
# 	 accepting R-DME-622312 Inflammasomes because overlap is 0
#
# 	 R-DME-844456 The NLRP3 inflammasome 3
# 	 rejecting R-DME-844456 The NLRP3 inflammasome because overlap is 1.0
#
# 	 R-DME-5578768 Physiological factors 4
# 	 accepting R-DME-5578768 Physiological factors because overlap is 0.5
#
# 	 R-DME-193144 Estrogen biosynthesis 4
# 	 rejecting R-DME-193144 Estrogen biosynthesis because overlap is 1.0
#
# 	 R-DME-112311 Neurotransmitter clearance 4
# 	 rejecting R-DME-112311 Neurotransmitter clearance because overlap is 1.0
#
# 	 R-DME-168643 Nucleotide-binding domain, leucine rich repeat containing receptor (NLR) signaling pathways 3
# 	 rejecting R-DME-168643 Nucleotide-binding domain, leucine rich repeat containing receptor (NLR) signaling pathways because overlap is 1.0
#
# 	 R-DME-9757110 Prednisone ADME 5
# 	 rejecting R-DME-9757110 Prednisone ADME because overlap is 1.0
#
# 	 R-DME-556833 Metabolism of lipids 16
# 	 accepting R-DME-556833 Metabolism of lipids because overlap is 0.375
#
# 	 R-DME-9749641 Aspirin ADME 4
# 	 rejecting R-DME-9749641 Aspirin ADME because overlap is 1.0
#
#
# h2low vs WT down
# 	 R-DME-3371497 HSP90 chaperone cycle for steroid hormone receptors (SHR) in the presence of ligand 5
# 	 accepting R-DME-3371497 HSP90 chaperone cycle for steroid hormone receptors (SHR) in the presence of ligand because overlap is 0
#
# 	 R-DME-6811442 Intra-Golgi and retrograde Golgi-to-ER traffic 5
# 	 accepting R-DME-6811442 Intra-Golgi and retrograde Golgi-to-ER traffic because overlap is 0.6
#
# 	 R-DME-9646399 Aggrephagy 3
# 	 rejecting R-DME-9646399 Aggrephagy because overlap is 1.0
#
# 	 R-DME-6811436 COPI-independent Golgi-to-ER retrograde traffic 3
# 	 rejecting R-DME-6811436 COPI-independent Golgi-to-ER retrograde traffic because overlap is 1.0

# %%
for content in terms_to_use:
    print(len(content), content)

print()

for top_ten in top_ten_categories:
    print(len(top_ten), top_ten)

union_list = list(set(item for sublist in top_ten_categories for item in sublist))

print()

print(len(union_list), union_list)
# Out:
# 18 ['R-DME-1428517', 'R-DME-9837999', 'R-DME-70263', 'R-DME-5628897', 'R-DME-71387', 'R-DME-8978868', 'R-DME-71291', 'R-DME-425407', 'R-DME-2022377', 'R-DME-211859', 'R-DME-196757', 'R-DME-556833', 'R-DME-397014', 'R-DME-5362517', 'R-DME-9748784', 'R-DME-196849', 'R-DME-196854', 'R-DME-112311']
# 10 ['R-DME-3371497', 'R-DME-425407', 'R-DME-6811442', 'R-DME-9663891', 'R-DME-1632852', 'R-DME-432040', 'R-DME-199977', 'R-DME-199991', 'R-DME-9793528', 'R-DME-8953897']
# 25 ['R-DME-1428517', 'R-DME-70895', 'R-DME-9837999', 'R-DME-211859', 'R-DME-71291', 'R-DME-428643', 'R-DME-8978868', 'R-DME-70263', 'R-DME-196854', 'R-DME-556833', 'R-DME-2022377', 'R-DME-5652084', 'R-DME-1852241', 'R-DME-9757110', 'R-DME-9748784', 'R-DME-5628897', 'R-DME-5661270', 'R-DME-9857492', 'R-DME-425407', 'R-DME-5362517', 'R-DME-983170', 'R-DME-71387', 'R-DME-168643', 'R-DME-8963743', 'R-DME-15869']
# 9 ['R-DME-8956320', 'R-DME-352230', 'R-DME-425407', 'R-DME-6798695', 'R-DME-382556', 'R-DME-9748784', 'R-DME-15869', 'R-DME-1474244', 'R-DME-9840310']
# 16 ['R-DME-8866654', 'R-DME-5689880', 'R-DME-73894', 'R-DME-8953897', 'R-DME-9663891', 'R-DME-70326', 'R-DME-1632852', 'R-DME-9716542', 'R-DME-70268', 'R-DME-432040', 'R-DME-71387', 'R-DME-8856688', 'R-DME-2980736', 'R-DME-112043', 'R-DME-425407', 'R-DME-9857492']
# 8 ['R-DME-425407', 'R-DME-8935690', 'R-DME-8956320', 'R-DME-556833', 'R-DME-5578768', 'R-DME-6798695', 'R-DME-2022377', 'R-DME-15869']
# 9 ['R-DME-9748784', 'R-DME-5653890', 'R-DME-3371497', 'R-DME-211945', 'R-DME-425407', 'R-DME-211859', 'R-DME-622312', 'R-DME-5578768', 'R-DME-556833']
# 2 ['R-DME-3371497', 'R-DME-6811442']
#
# 10 ['R-DME-1428517', 'R-DME-9837999', 'R-DME-70263', 'R-DME-5628897', 'R-DME-71387', 'R-DME-8978868', 'R-DME-71291', 'R-DME-425407', 'R-DME-2022377', 'R-DME-211859']
# 10 ['R-DME-3371497', 'R-DME-425407', 'R-DME-6811442', 'R-DME-9663891', 'R-DME-1632852', 'R-DME-432040', 'R-DME-199977', 'R-DME-199991', 'R-DME-9793528', 'R-DME-8953897']
# 10 ['R-DME-1428517', 'R-DME-70895', 'R-DME-9837999', 'R-DME-211859', 'R-DME-71291', 'R-DME-428643', 'R-DME-8978868', 'R-DME-70263', 'R-DME-196854', 'R-DME-556833']
# 9 ['R-DME-8956320', 'R-DME-352230', 'R-DME-425407', 'R-DME-6798695', 'R-DME-382556', 'R-DME-9748784', 'R-DME-15869', 'R-DME-1474244', 'R-DME-9840310']
# 10 ['R-DME-8866654', 'R-DME-5689880', 'R-DME-73894', 'R-DME-8953897', 'R-DME-9663891', 'R-DME-70326', 'R-DME-1632852', 'R-DME-9716542', 'R-DME-70268', 'R-DME-432040']
# 8 ['R-DME-425407', 'R-DME-8935690', 'R-DME-8956320', 'R-DME-556833', 'R-DME-5578768', 'R-DME-6798695', 'R-DME-2022377', 'R-DME-15869']
# 9 ['R-DME-9748784', 'R-DME-5653890', 'R-DME-3371497', 'R-DME-211945', 'R-DME-425407', 'R-DME-211859', 'R-DME-622312', 'R-DME-5578768', 'R-DME-556833']
# 2 ['R-DME-3371497', 'R-DME-6811442']
#
# 42 ['R-DME-70263', 'R-DME-5689880', 'R-DME-8953897', 'R-DME-9663891', 'R-DME-428643', 'R-DME-9716542', 'R-DME-8956320', 'R-DME-9837999', 'R-DME-5578768', 'R-DME-352230', 'R-DME-425407', 'R-DME-211859', 'R-DME-432040', 'R-DME-1632852', 'R-DME-70268', 'R-DME-199977', 'R-DME-15869', 'R-DME-71291', 'R-DME-70326', 'R-DME-211945', 'R-DME-622312', 'R-DME-73894', 'R-DME-382556', 'R-DME-71387', 'R-DME-5653890', 'R-DME-6798695', 'R-DME-2022377', 'R-DME-196854', 'R-DME-8935690', 'R-DME-70895', 'R-DME-8978868', 'R-DME-9840310', 'R-DME-199991', 'R-DME-9793528', 'R-DME-3371497', 'R-DME-9748784', 'R-DME-556833', 'R-DME-6811442', 'R-DME-5628897', 'R-DME-8866654', 'R-DME-1474244', 'R-DME-1428517']

# %%
terms_used_so_far = {}
depth = 0
print(terms_to_use)
for i in range(len(terms_to_use)):
    for j in range(len(terms_to_use[i])):
        element = terms_to_use[i][j]

        if element in union_list:
        
            if element in terms_used_so_far.keys():
                location = terms_used_so_far[element]
            else:
                depth = depth - 1
                location = depth
    
            # define color
            adjp = -numpy.log10(df[(df['ID'] == element) & (df['Cluster'] == contrasts[i])]['p.adjust'].values[0])
            #print(element, adjp)
    
            # define size
            thesize = int(df[(df['ID'] == element) & (df['Cluster'] == contrasts[i])]['GeneRatio'].values[0].split('/')[0])
            
            # make a point        
            matplotlib.pyplot.scatter(i, location, s=thesize*5, c=adjp, zorder=9999, cmap='cividis', vmin=-numpy.log10(0.05), vmax=20)
    
            terms_used_so_far[element] = location


matplotlib.pyplot.colorbar(label='-log10 adj. P', ticks=[5, 10, 15, 20])

# close the figure
a = []; b = []
for element in terms_used_so_far.keys():
    description = list(df[df['ID'] == element]['Description'].values)[0]
    a.append(description)
    b.append(terms_used_so_far[element])

for area in 5*numpy.array([5, 20, 80]):
    matplotlib.pyplot.scatter([], [], c='black', edgecolor=None, s=area, label=str(int(area/5)))
matplotlib.pyplot.legend(loc=3)

matplotlib.pyplot.yticks(b, a, fontsize=12)
matplotlib.pyplot.xticks([0, 1, 2, 3, 4, 5, 6, 7], 
                         ['KO vs WT up', 'KO vs WT down', 'high vs WT up', 'high vs WT down', 'high vs KO up', 'high vs KO down', 'low vs WT up', 'low vs WT down'], 
                         rotation=-90)
 
# ko vs wt
# high vs wt
# high vs ko
# low vs wt

matplotlib.pyplot.ylim(-40.75, -0.25)
matplotlib.pyplot.grid(ls=':')
matplotlib.pyplot.tight_layout()

#matplotlib.pyplot.show()
matplotlib.pyplot.savefig('enrichment.svg')
# Out:
# [['R-DME-1428517', 'R-DME-9837999', 'R-DME-70263', 'R-DME-5628897', 'R-DME-71387', 'R-DME-8978868', 'R-DME-71291', 'R-DME-425407', 'R-DME-2022377', 'R-DME-211859', 'R-DME-196757', 'R-DME-556833', 'R-DME-397014', 'R-DME-5362517', 'R-DME-9748784', 'R-DME-196849', 'R-DME-196854', 'R-DME-112311'], ['R-DME-3371497', 'R-DME-425407', 'R-DME-6811442', 'R-DME-9663891', 'R-DME-1632852', 'R-DME-432040', 'R-DME-199977', 'R-DME-199991', 'R-DME-9793528', 'R-DME-8953897'], ['R-DME-1428517', 'R-DME-70895', 'R-DME-9837999', 'R-DME-211859', 'R-DME-71291', 'R-DME-428643', 'R-DME-8978868', 'R-DME-70263', 'R-DME-196854', 'R-DME-556833', 'R-DME-2022377', 'R-DME-5652084', 'R-DME-1852241', 'R-DME-9757110', 'R-DME-9748784', 'R-DME-5628897', 'R-DME-5661270', 'R-DME-9857492', 'R-DME-425407', 'R-DME-5362517', 'R-DME-983170', 'R-DME-71387', 'R-DME-168643', 'R-DME-8963743', 'R-DME-15869'], ['R-DME-8956320', 'R-DME-352230', 'R-DME-425407', 'R-DME-6798695', 'R-DME-382556', 'R-DME-9748784', 'R-DME-15869', 'R-DME-1474244', 'R-DME-9840310'], ['R-DME-8866654', 'R-DME-5689880', 'R-DME-73894', 'R-DME-8953897', 'R-DME-9663891', 'R-DME-70326', 'R-DME-1632852', 'R-DME-9716542', 'R-DME-70268', 'R-DME-432040', 'R-DME-71387', 'R-DME-8856688', 'R-DME-2980736', 'R-DME-112043', 'R-DME-425407', 'R-DME-9857492'], ['R-DME-425407', 'R-DME-8935690', 'R-DME-8956320', 'R-DME-556833', 'R-DME-5578768', 'R-DME-6798695', 'R-DME-2022377', 'R-DME-15869'], ['R-DME-9748784', 'R-DME-5653890', 'R-DME-3371497', 'R-DME-211945', 'R-DME-425407', 'R-DME-211859', 'R-DME-622312', 'R-DME-5578768', 'R-DME-556833'], ['R-DME-3371497', 'R-DME-6811442']]
# /var/folders/j2/645ctp717nv8rwbn2dsccyxh0000gn/T/ipykernel_37069/2272269473.py:54: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   matplotlib.pyplot.tight_layout()
