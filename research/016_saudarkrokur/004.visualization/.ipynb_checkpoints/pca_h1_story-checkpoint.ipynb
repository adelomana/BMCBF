# %%
import pandas, numpy

# %%
import sklearn, sklearn.preprocessing, sklearn.decomposition

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(2/3), 9*(2/3)), 
                            'axes.labelsize':20
                           })

# %% [markdown]
# # 0. user-defined variables

# %%
input_file = '/Users/adrian/research/016.saudarkrokur/results/deseq2/DESeq2_TPM_values.tsv'

# %% [markdown]
# # 1. read expression

# %%
expression = pandas.read_csv(input_file, sep='\t', index_col=0)
print(expression.shape)
expression
# Out:
# (20196, 15)
#                                  h1M8_1     h1M8_2     h1M8_3    h2F14_1  \
# FBgn0000008                    7.888992   2.404364   7.641325   4.496739
# FBgn0000014                   20.584356   9.116074  16.522137  15.028010
# FBgn0000015                    4.750318   2.421290   4.041314   3.888815
# FBgn0000017                   18.593702  10.642545  16.094865  12.066664
# FBgn0000018                    7.344876   5.077850   5.495519   6.130012
# ...                                 ...        ...        ...        ...
# RR51048_transposable_element   0.000000   0.000000   0.000000   0.000000
# RR51093_transposable_element   0.000000   0.000000   0.378845   0.000000
# RR51475_transposable_element   0.731425   1.404666   2.041584   0.587566
# RR51477_transposable_element   0.009972   0.017888   0.021606   0.021574
# RR51478_transposable_element   0.000000   0.000000   0.000000   0.000000
#
#                                 h2F14_2    h2F14_3     h2M8_1     h2M8_2  \
# FBgn0000008                    4.474108   3.101558   4.169942   1.109283
# FBgn0000014                   21.370556  14.917465   8.706565   3.393639
# FBgn0000015                    5.497831   3.691880   3.295904   1.335717
# FBgn0000017                   15.937162   4.499557   9.407700   3.693964
# FBgn0000018                    5.916365   5.738847   6.771208   4.022657
# ...                                 ...        ...        ...        ...
# RR51048_transposable_element   0.010833   0.000000   0.000000   0.013156
# RR51093_transposable_element   0.391035   1.290643   0.098497   1.382451
# RR51475_transposable_element   1.355312  17.322956  10.440089  45.617028
# RR51477_transposable_element   0.005813   0.014672   0.098988   0.085491
# RR51478_transposable_element   0.000000   0.000000   0.000000   0.000000
#
#                                 h2M8_3      KO_1       KO_2      KO_3  \
# FBgn0000008                   2.990706  1.868627   6.349273  2.046127
# FBgn0000014                   9.797755  9.116257  13.886094  7.729379
# FBgn0000015                   2.375402  2.341026   4.271938  2.319874
# FBgn0000017                   8.149117  6.646698   9.728445  5.603754
# FBgn0000018                   6.456481  4.897385   5.102448  3.645305
# ...                                ...       ...        ...       ...
# RR51048_transposable_element  0.000000  0.017752   0.017819  0.000000
# RR51093_transposable_element  0.222965  0.232897   0.465807  0.000000
# RR51475_transposable_element  5.626746  4.394941   2.425542  2.004484
# RR51477_transposable_element  0.032967  0.009189   0.033684  0.016833
# RR51478_transposable_element  0.000000  0.000000   0.000000  0.000000
#
#                                    WT_1       WT_2       WT_3
# FBgn0000008                    3.973536   4.069418  13.169861
# FBgn0000014                   17.593189  17.433641  26.561830
# FBgn0000015                    5.166222   4.948848   5.854713
# FBgn0000017                   13.220405  15.056392  19.031383
# FBgn0000018                    8.031238   8.084451   6.875136
# ...                                 ...        ...        ...
# RR51048_transposable_element   0.109559   0.000000   0.098044
# RR51093_transposable_element   0.398241   0.560288   0.201621
# RR51475_transposable_element  13.506209  17.595002   7.525028
# RR51477_transposable_element   0.042574   0.000000   0.106921
# RR51478_transposable_element   0.000000   0.000000   0.000000
#
# [20196 rows x 15 columns]

# %%
samples_to_exclude = ['h2M8_1', 'h2M8_2', 'h2M8_3', 'h2F14_1', 'h2F14_2', 'h2F14_3']
expression.drop(samples_to_exclude, axis=1, inplace=True)

# %%
expression
# Out:
#                                  h1M8_1     h1M8_2     h1M8_3      KO_1  \
# FBgn0000008                    7.888992   2.404364   7.641325  1.868627
# FBgn0000014                   20.584356   9.116074  16.522137  9.116257
# FBgn0000015                    4.750318   2.421290   4.041314  2.341026
# FBgn0000017                   18.593702  10.642545  16.094865  6.646698
# FBgn0000018                    7.344876   5.077850   5.495519  4.897385
# ...                                 ...        ...        ...       ...
# RR51048_transposable_element   0.000000   0.000000   0.000000  0.017752
# RR51093_transposable_element   0.000000   0.000000   0.378845  0.232897
# RR51475_transposable_element   0.731425   1.404666   2.041584  4.394941
# RR51477_transposable_element   0.009972   0.017888   0.021606  0.009189
# RR51478_transposable_element   0.000000   0.000000   0.000000  0.000000
#
#                                    KO_2      KO_3       WT_1       WT_2  \
# FBgn0000008                    6.349273  2.046127   3.973536   4.069418
# FBgn0000014                   13.886094  7.729379  17.593189  17.433641
# FBgn0000015                    4.271938  2.319874   5.166222   4.948848
# FBgn0000017                    9.728445  5.603754  13.220405  15.056392
# FBgn0000018                    5.102448  3.645305   8.031238   8.084451
# ...                                 ...       ...        ...        ...
# RR51048_transposable_element   0.017819  0.000000   0.109559   0.000000
# RR51093_transposable_element   0.465807  0.000000   0.398241   0.560288
# RR51475_transposable_element   2.425542  2.004484  13.506209  17.595002
# RR51477_transposable_element   0.033684  0.016833   0.042574   0.000000
# RR51478_transposable_element   0.000000  0.000000   0.000000   0.000000
#
#                                    WT_3
# FBgn0000008                   13.169861
# FBgn0000014                   26.561830
# FBgn0000015                    5.854713
# FBgn0000017                   19.031383
# FBgn0000018                    6.875136
# ...                                 ...
# RR51048_transposable_element   0.098044
# RR51093_transposable_element   0.201621
# RR51475_transposable_element   7.525028
# RR51477_transposable_element   0.106921
# RR51478_transposable_element   0.000000
#
# [20196 rows x 9 columns]

# %% [markdown]
# # 3. filter and transform

# %%
substantial_expression = expression[expression.max(axis=1) >= 10]
high_expression = expression[expression.max(axis=1) >= 200]

print(substantial_expression.shape)
print(high_expression.shape)
# Out:
# (6933, 9)
# (758, 9)

# %%
transpose = substantial_expression.transpose()
pca_substantial_expression = numpy.log2(transpose + 1)

transpose = high_expression.transpose()
pca_high_expression = numpy.log2(transpose + 1)

# %% [markdown]
# # 4. visualize substantial expression

# %%
scaled_data = sklearn.preprocessing.StandardScaler().fit_transform(pca_substantial_expression)
model = sklearn.decomposition.PCA(n_components=2)
new = model.fit_transform(scaled_data)
explained = model.explained_variance_ratio_
print(explained)
# Out:
# [0.52226503 0.13365266]

# %%
my_colors = ['gold']*3 + ['black']*3 + ['tab:green']*3
my_markers = ['o']*3 + ['s']*6

legend_elements = [
    
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='gold', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='s', markerfacecolor='black', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='s', markerfacecolor='tab:green', markeredgecolor='white', markersize=20, alpha=2/3)
    
]

for i in range(len(new)):
    matplotlib.pyplot.scatter(new[i,0], new[i,1], s=666, c=my_colors[i], marker=my_markers[i], alpha=2/3, edgecolors='none')
    epsilon = 1
    matplotlib.pyplot.text(new[i,0]+epsilon, new[i,1]+epsilon, expression.columns[i], size=12)

matplotlib.pyplot.legend(legend_elements, ['h1', 'KO', 'WT'], ncol=2, loc='upper left', bbox_to_anchor=(1.05, 1))
    
matplotlib.pyplot.xlabel('PC1 (exp. var.: {}%)'.format(int(explained[0]*100)))
matplotlib.pyplot.ylabel('PC2 (exp. var.: {}%)'.format(int(explained[1]*100)))
matplotlib.pyplot.grid(alpha=0.5, ls=':')

matplotlib.pyplot.show()

# %% [markdown]
# # 4. visualize high expression

# %%
scaled_data = sklearn.preprocessing.StandardScaler().fit_transform(pca_high_expression)
model = sklearn.decomposition.PCA(n_components=2)
new = model.fit_transform(scaled_data)
explained = model.explained_variance_ratio_
print(explained)
# Out:
# [0.39643664 0.18213652]

# %%
my_colors = ['gold']*3 + ['black']*3 + ['tab:green']*3
my_markers = ['o']*3 + ['s']*6

legend_elements = [
    
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='gold', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='s', markerfacecolor='black', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='s', markerfacecolor='tab:green', markeredgecolor='white', markersize=20, alpha=2/3)
    
]

for i in range(len(new)):
    matplotlib.pyplot.scatter(new[i,0], -new[i,1], s=666, c=my_colors[i], marker=my_markers[i], alpha=2/3, edgecolors='none')
    epsilon = 1
    matplotlib.pyplot.text(new[i,0]+epsilon, -new[i,1]-epsilon, expression.columns[i], size=12)

matplotlib.pyplot.legend(legend_elements, ['h1', 'KO', 'WT'], ncol=1, loc='upper left', bbox_to_anchor=(1.05, 1))
    
matplotlib.pyplot.xlabel('PC1 (exp. var.: {}%)'.format(int(explained[0]*100)))
matplotlib.pyplot.ylabel('PC2 (exp. var.: {}%)'.format(int(explained[1]*100)))
matplotlib.pyplot.grid(alpha=0.5, ls=':')

#matplotlib.pyplot.show()
matplotlib.pyplot.savefig('pca_triad.svg')
