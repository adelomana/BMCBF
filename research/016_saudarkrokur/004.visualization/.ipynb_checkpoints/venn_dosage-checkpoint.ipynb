# %%
import supervenn, pandas, matplotlib_venn

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(2/3), 9*(2/3)), 
                            'axes.labelsize':20
                           })

# %% [markdown]
# # define annotations for later

# %%
annotation_file = '/Users/adrian/research/016.saudarkrokur/results/deseq2/annotation.tsv'
annotation = pandas.read_csv(annotation_file, sep='\t')
annotation
# Out:
#        Unnamed: 0 ensembl_transcript_id ensembl_gene_id external_gene_name  \
# 0               1           FBtr0343930     FBgn0029843               Nep1
# 1               2           FBtr0070872     FBgn0029843               Nep1
# 2               3           FBtr0070873     FBgn0029843               Nep1
# 3               4           FBtr0340032     FBgn0029843               Nep1
# 4               5           FBtr0343977     FBgn0266278     lncRNA:CR44963
# ...           ...                   ...             ...                ...
# 43863       43864           FBtr0300149     FBgn0259851    Su(Ste):CR42420
# 43864       43865           FBtr0074055     FBgn0030673            CG15601
# 43865       43866           FBtr0339685     FBgn0030673            CG15601
# 43866       43867           FBtr0339683     FBgn0030673            CG15601
# 43867       43868           FBtr0339684     FBgn0030673            CG15601
#
#        entrezgene_id    gene_biotype                  description
# 0            31547.0  protein_coding                 Neprilysin 1
# 1            31547.0  protein_coding                 Neprilysin 1
# 2            31547.0  protein_coding                 Neprilysin 1
# 3            31547.0  protein_coding                 Neprilysin 1
# 4         19835737.0           ncRNA  long non-coding RNA:CR44963
# ...              ...             ...                          ...
# 43863      7354455.0           ncRNA              Su(Ste):CR42420
# 43864        32509.0  protein_coding                          NaN
# 43865        32509.0  protein_coding                          NaN
# 43866        32509.0  protein_coding                          NaN
# 43867        32509.0  protein_coding                          NaN
#
# [43868 rows x 7 columns]

# %% [markdown]
# # super venn

# %%
input_dir = '/Users/adrian/research/016.saudarkrokur/results/deseq2/'

df = pandas.read_csv(input_dir+'effect_h2F14_wt.tsv', sep='\t', index_col=0)
a = set(df.index)
print(len(a))

df = pandas.read_csv(input_dir+'effect_h2M8_wt.tsv', sep='\t', index_col=0)
b = set(df.index)
print(len(b))

df = pandas.read_csv(input_dir+'effect_h2M8_h2F14.tsv', sep='\t', index_col=0)
c = set(df.index)
print(len(c))
# Out:
# 531
# 1273
# 677

# %%
sets = [a, b, c]
labels = ['effect_h2F14_wt', 'effect_h2M8_wt', 'effect_h2M8_h2F14']
mso = supervenn.supervenn(sets, labels,
                          side_plots=False, chunks_ordering='size', 
                          reverse_sets_order=False, fontsize=8, color_cycle=['skyblue', 'tab:red', 'tab:green'])

matplotlib.pyplot.show()
