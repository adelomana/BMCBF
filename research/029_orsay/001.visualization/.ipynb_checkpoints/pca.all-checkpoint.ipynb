# %%
import pandas, numpy, scipy

# %%
import sklearn, sklearn.preprocessing, sklearn.decomposition

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(3/3), 9*(3/3)), 
                            'axes.labelsize':20
                           })

# %% [markdown]
# # 0. read metadata

# %%
input_file = '/Users/adrian/research/bmcbf/029_orsay/metadata/SampleDescription-annotated.xlsx'
metadata = pandas.read_excel(input_file)

# %% [markdown]
# # 1. read expression

# %%
input_file = '/Users/adrian/research/bmcbf/029_orsay/results/000.quantification/results/DESeq2_TPM_values.tsv'
expression = pandas.read_csv(input_file, sep='\t', index_col=0)
print(expression.shape)
expression
# Out:
# (34183, 34)
#                           P9T001     P9T002     P9T003     P9T004     P9T005  \
# ENSMUSG00000000001.5   52.590418  61.495779  53.125823  54.347540  59.766875
# ENSMUSG00000000003.16   0.000000   0.000000   0.000000   0.000000   0.000000
# ENSMUSG00000000028.16   3.074236   9.866062   6.699898   4.222149   6.381881
# ENSMUSG00000000031.18   7.029637  96.835916   6.403240  13.898170  18.527473
# ENSMUSG00000000037.18   1.133755   7.668860   4.315301   1.963341   5.148476
# ...                          ...        ...        ...        ...        ...
# ENSMUSG00000121512.1    0.000000   0.000000   0.000000   0.000000   0.000000
# ENSMUSG00000121513.1   34.708126  10.686098  15.211993  38.435779  13.310473
# ENSMUSG00001074846.1    0.000000   0.000000   0.000000   0.000000   0.000000
# ENSMUSG00002075770.1    0.000000   0.000000   0.000000   0.000000   0.000000
# ENSMUSG00002076083.1   50.037898  43.945328  42.354059  33.343652  48.693270
#
# ...

# %%
metadata["mouse Nb"] = metadata["mouse Nb"].astype(str)
mapping = dict(zip(metadata["NAME"], metadata["mouse Nb"]))
expression = expression.rename(columns=mapping)
expression
# Out:
#                              376       2423       2651       2727       2764  \
# ENSMUSG00000000001.5   52.590418  61.495779  53.125823  54.347540  59.766875
# ENSMUSG00000000003.16   0.000000   0.000000   0.000000   0.000000   0.000000
# ENSMUSG00000000028.16   3.074236   9.866062   6.699898   4.222149   6.381881
# ENSMUSG00000000031.18   7.029637  96.835916   6.403240  13.898170  18.527473
# ENSMUSG00000000037.18   1.133755   7.668860   4.315301   1.963341   5.148476
# ...                          ...        ...        ...        ...        ...
# ENSMUSG00000121512.1    0.000000   0.000000   0.000000   0.000000   0.000000
# ENSMUSG00000121513.1   34.708126  10.686098  15.211993  38.435779  13.310473
# ENSMUSG00001074846.1    0.000000   0.000000   0.000000   0.000000   0.000000
# ENSMUSG00002075770.1    0.000000   0.000000   0.000000   0.000000   0.000000
# ENSMUSG00002076083.1   50.037898  43.945328  42.354059  33.343652  48.693270
#
# ...

# %% [markdown]
# # 3. filter and transform

# %%
substantial_expression = expression[expression.max(axis=1) >= 2]
high_expression = expression[expression.max(axis=1) >= 100]

print(substantial_expression.shape)
print(high_expression.shape)
# Out:
# (15735, 34)
# (2586, 34)

# %%
transpose = substantial_expression.transpose()
pca_substantial_expression = numpy.log2(transpose + 1)

transpose = high_expression.transpose()
pca_high_expression = numpy.log2(transpose + 1)

# %% [markdown]
# # 4. visualize substantial expression

# %%
scaled_data = sklearn.preprocessing.StandardScaler().fit_transform(pca_substantial_expression)
model = sklearn.decomposition.PCA(n_components=2)
new = model.fit_transform(scaled_data)
explained = model.explained_variance_ratio_
print(explained)
# Out:
# [0.21685263 0.13398804]

# %%
expression.columns
# Out:
# Index(['376', '2423', '2651', '2727', '2764', '2773', '2423B', '2773B', '376B',
#        '2346', '2409', '2426', '2513', '2657', '2728', '2409B', '2657B',
#        '2728B', '2101', '2102', '2105', '2239', '2344', '2370', '2371', '2376',
#        '2383', '2403', '2105B', '2239B', '326', '390', '388B', '390B'],
#       dtype='object')

# %%
metadata['genotype'].unique()
# Out:
# array([' wt', ' het', ' hom', ' Vga/F'], dtype=object)

# %%
# define color map
unique_groups = metadata['genotype'].unique()
palette = ['black', "gold", "tab:red", "skyblue"]
color_map = {group: color for group, color in zip(unique_groups, palette)}
color_map
# Out:
# {' wt': 'black', ' het': 'gold', ' hom': 'tab:red', ' Vga/F': 'skyblue'}

# %%
for i in range(len(new)):

    # colors
    sampleid = expression.columns[i]
    genotype = metadata[metadata['mouse Nb'] == sampleid]['genotype'].values[0]
    the_color = color_map[genotype]
    print(sampleid, the_color)
    
    matplotlib.pyplot.scatter(new[i,0], new[i,1], s=200, c=the_color, marker='o', alpha=2/3, edgecolors='none')
    epsilon = 1
    matplotlib.pyplot.text(new[i,0]+epsilon, new[i,1]+epsilon, sampleid, size=8)

legend_elements = [
    
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='black', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='gold', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='tab:red', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='s', markerfacecolor='skyblue', markeredgecolor='white', markersize=20, alpha=2/3)
    
]

matplotlib.pyplot.legend(legend_elements, ['WT', 'HET', 'HOM', 'VGA'], ncol=1, loc='upper left', bbox_to_anchor=(1.05, 1))
    
matplotlib.pyplot.xlabel('PC1 (exp. var.: {}%)'.format(int(explained[0]*100)))
matplotlib.pyplot.ylabel('PC2 (exp. var.: {}%)'.format(int(explained[1]*100)))
matplotlib.pyplot.grid(alpha=0.5, ls=':')

matplotlib.pyplot.show()
# Out:
# 376 black
# 2423 black
# 2651 black
# 2727 black
# 2764 black
# 2773 black
# 2423B black
# 2773B black
# 376B black
# 2346 gold
# 2409 gold
# 2426 gold
# 2513 gold
# 2657 gold
# 2728 gold
# 2409B gold
# 2657B gold
# 2728B gold
# 2101 tab:red
# 2102 tab:red
# 2105 tab:red
# 2239 tab:red
# 2344 tab:red
# 2370 tab:red
# 2371 tab:red
# 2376 tab:red
# 2383 tab:red
# 2403 tab:red
# 2105B tab:red
# 2239B tab:red
# 326 skyblue
# 390 skyblue
# 388B skyblue
# 390B skyblue

# %% [markdown]
# # 4. visualize high expression

# %%
scaled_data = sklearn.preprocessing.StandardScaler().fit_transform(pca_high_expression)
model = sklearn.decomposition.PCA(n_components=2)
new = model.fit_transform(scaled_data)
explained = model.explained_variance_ratio_
print(explained)
# Out:
# [0.2613831  0.15142115]

# %%
for i in range(len(new)):

    # colors
    sampleid = expression.columns[i]
    genotype = metadata[metadata['mouse Nb'] == sampleid]['genotype'].values[0]
    the_color = color_map[genotype]

    # markers
    if 'B' in sampleid:
        the_marker = '*'
    else:
        the_marker = 'o'
    
    matplotlib.pyplot.scatter(new[i,0], new[i,1], s=200, c=the_color, marker=the_marker, alpha=2/3, edgecolors='none')
    epsilon = 1
    matplotlib.pyplot.text(new[i,0]+epsilon, new[i,1]+epsilon, sampleid, size=8)

legend_elements = [
    
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='black', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='gold', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='tab:red', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='s', markerfacecolor='skyblue', markeredgecolor='white', markersize=20, alpha=2/3)
    
]

matplotlib.pyplot.legend(legend_elements, ['WT', 'HET', 'HOM', 'VGA'], ncol=1, loc='upper left', bbox_to_anchor=(1.05, 1))
    
matplotlib.pyplot.xlabel('PC1 (exp. var.: {}%)'.format(int(explained[0]*100)))
matplotlib.pyplot.ylabel('PC2 (exp. var.: {}%)'.format(int(explained[1]*100)))
matplotlib.pyplot.grid(alpha=0.5, ls=':')

matplotlib.pyplot.show()

# %%
### 6. second extractions exclusions

"""
exclussions at this point is very difficult, but using some biased intuition, I would go for:

Black. 376, 376B because is a weird mouse. and 2727 bc of the distribution. 2773B and 2423B to keep it low
yellow. 2728B, 2409B and 2657B to keep it low, close to wt
red. 2105 and 2239 to keep consistency high
Blues. 390 so we move higher
"""

print(len(expression.columns), expression.columns)
sub_expression = high_expression.drop(columns=["376", "376B", "2727", '2773B', '2423B'])
sub_expression = sub_expression.drop(columns=["2728B", "2409B", "2657B"])
sub_expression = sub_expression.drop(columns=["2105", "2239"])
sub_expression = sub_expression.drop(columns=["390"])
print(len(sub_expression.columns))

transpose = sub_expression.transpose()
pca_sub_expression = numpy.log2(transpose + 1)

scaled_data = sklearn.preprocessing.StandardScaler().fit_transform(pca_sub_expression)
model = sklearn.decomposition.PCA(n_components=2)
new = model.fit_transform(scaled_data)
explained = model.explained_variance_ratio_
print(explained)

for i in range(len(new)):

    # colors
    sampleid = sub_expression.columns[i]
    genotype = metadata[metadata['mouse Nb'] == sampleid]['genotype'].values[0]
    the_color = color_map[genotype]

    # markers
    if 'B' in sampleid:
        the_marker = '*'
    else:
        the_marker = 'o'
    
    matplotlib.pyplot.scatter(new[i,0], new[i,1], s=200, c=the_color, marker=the_marker, alpha=2/3, edgecolors='none')
    epsilon = 1
    matplotlib.pyplot.text(new[i,0]+epsilon, new[i,1]+epsilon, sampleid, size=8)

legend_elements = [
    
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='black', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='gold', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='o', markerfacecolor='tab:red', markeredgecolor='white', markersize=20, alpha=2/3),
    matplotlib.lines.Line2D([0], [0], color='white', marker='s', markerfacecolor='skyblue', markeredgecolor='white', markersize=20, alpha=2/3)
    
]

matplotlib.pyplot.legend(legend_elements, ['WT', 'HET', 'HOM', 'VGA'], ncol=1, loc='upper left', bbox_to_anchor=(1.05, 1))
    
matplotlib.pyplot.xlabel('PC1 (exp. var.: {}%)'.format(int(explained[0]*100)))
matplotlib.pyplot.ylabel('PC2 (exp. var.: {}%)'.format(int(explained[1]*100)))
matplotlib.pyplot.grid(alpha=0.5, ls=':')
# Out:
# 34 Index(['376', '2423', '2651', '2727', '2764', '2773', '2423B', '2773B', '376B',
#        '2346', '2409', '2426', '2513', '2657', '2728', '2409B', '2657B',
#        '2728B', '2101', '2102', '2105', '2239', '2344', '2370', '2371', '2376',
#        '2383', '2403', '2105B', '2239B', '326', '390', '388B', '390B'],
#       dtype='object')
# 23
# [0.19747061 0.16628105]

# %%
# 5. distributions

# %%
log2_tpm_PO = numpy.log2(expression + 1)
log2_tpm_PO.head()
# Out:
#                             376      2423      2651      2727      2764  \
# ENSMUSG00000000001.5   5.743903  5.965687  5.758245  5.790447  5.925213
# ENSMUSG00000000003.16  0.000000  0.000000  0.000000  0.000000  0.000000
# ENSMUSG00000000028.16  2.026530  3.441757  2.944839  2.384644  2.883989
# ENSMUSG00000000031.18  3.005335  6.612292  2.888157  3.897063  4.287433
# ENSMUSG00000000037.18  1.093395  3.115842  2.410152  1.567225  2.620229
#
#                            2773     2423B     2773B      376B      2346  ...  \
# ENSMUSG00000000001.5   6.036533  6.000634  6.315856  5.622955  5.963153  ...
# ENSMUSG00000000003.16  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# ENSMUSG00000000028.16  3.349468  3.436069  3.216339  2.144037  2.771126  ...
# ENSMUSG00000000031.18  5.704917  5.377837  7.282669  3.714617  4.828599  ...
# ENSMUSG00000000037.18  2.499820  3.611192  3.153810  1.505153  2.756073  ...
#
# ...

# %%
found_max = 15.1
number_of_bins = int(found_max*10)
print(number_of_bins)

absolute_max = 0
working_samples = log2_tpm_PO.columns.to_list()

most_likely_expressions = []
all_hats = []
for i in range(len(working_samples)):

    sample = working_samples[i]
    
    the_color = 'black'; the_alpha = 1/10
    if sample == '2727':
        the_color = 'tab:orange'; the_alpha = 1
    if sample == '376':
        the_color = 'tab:red'; the_alpha = 1
    if sample == '376B':
        the_color = 'tab:red'; the_alpha = 1
    
    log2TPM = log2_tpm_PO.loc[:, sample]
    if max(log2TPM) > absolute_max:
        absolute_max = max(log2TPM)
                
    hist, bin_edges = numpy.histogram(log2TPM, bins=number_of_bins, range=(0, found_max))
    half_bin = (bin_edges[1] - bin_edges[0])/2
    x = bin_edges + half_bin
    x = x[:-1]
  
    plotting_x = x[5:-20]
    plotting_hist = hist[5:-20]
    #print(plotting_x)
    
    #matplotlib.pyplot.plot(plotting_x, plotting_hist, '.', alpha=1/100, mec='none', color=the_color)
    yhat = scipy.signal.savgol_filter(plotting_hist, 51, 3)

    matplotlib.pyplot.plot(plotting_x, yhat, '-', lw=2, alpha=the_alpha, color=the_color)
    
matplotlib.pyplot.xlim([numpy.min(plotting_x)-0.25, numpy.max(plotting_x)+0.25])
#matplotlib.pyplot.ylim([0, 400])

matplotlib.pyplot.xlabel('log2 (TPM+1)')
matplotlib.pyplot.ylabel('Gene count')
matplotlib.pyplot.grid(ls=':')

matplotlib.pyplot.tight_layout()

print(absolute_max)
# Out:
# 151
# 15.007761024957459
