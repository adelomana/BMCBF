# %%
import pandas, supervenn

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(2/3), 9*(2/3)), 
                            'axes.labelsize':20
                           })

# %%
input_dir = '/Users/adrian/research/bmcbf/029_orsay/results/001.degs/'

df = pandas.read_csv(input_dir+'effect_HET_vs_WT.woo.for.tsv', sep='\t', index_col=0)
a = set(df.index)
print(len(a))

df = pandas.read_csv(input_dir+'effect_HOM_vs_WT.woo.for.tsv', sep='\t', index_col=0)
b = set(df.index)
print(len(b))

df = pandas.read_csv(input_dir+'effect_VGA_vs_WT.woo.for.tsv', sep='\t', index_col=0)
c = set(df.index)
print(len(c))

sets = [a, b, c]
labels = ['HET', 'HOM', 'VGA']
mso = supervenn.supervenn(sets, labels, chunks_ordering='size',
                          side_plots=False, widths_minmax_ratio=0.03, 
                          reverse_sets_order=False, fontsize=12, color_cycle=['gold', 'tab:red', 'skyblue'])


matplotlib.pyplot.tight_layout()

onlyhom = list(mso.get_chunk([1]))
onlyvga = list(mso.get_chunk([2]))
both = list(mso.get_chunk([1,2]))
print(len(onlyhom), len(onlyvga), len(both))

onlyhom.sort()
print(onlyhom)
onlyvga.sort()
both.sort()

annotation = pandas.read_csv('/Users/adrian/software/kallisto/mouse_index_standard/t2g.txt', sep='\t', header=None)
nodots = annotation[1].str.split('.', expand=True)
annotation['nodots'] = nodots[0]

selected_set = both
print(len(selected_set))

for i in range(len(selected_set)):    
    element = selected_set[i]
    most_likely = list(set(annotation[annotation['nodots'] == element][2]))
    if len(most_likely) != 1:
        print(most_likely)
        raise ValueError("Something went wrong. Stopping execution.")
    if type(most_likely[0]) == str:
        print(most_likely[0])
    else:
        print(element)
# Out:
# 4
# 192
# 230
# 140 180 49
# ['ENSMUSG00000000031', 'ENSMUSG00000000184', 'ENSMUSG00000000290', 'ENSMUSG00000000318', 'ENSMUSG00000002265', 'ENSMUSG00000002831', 'ENSMUSG00000007682', 'ENSMUSG00000008845', 'ENSMUSG00000012705', 'ENSMUSG00000015476', 'ENSMUSG00000017344', 'ENSMUSG00000019124', 'ENSMUSG00000019577', 'ENSMUSG00000019932', 'ENSMUSG00000020098', 'ENSMUSG00000020431', 'ENSMUSG00000020911', 'ENSMUSG00000020937', 'ENSMUSG00000021390', 'ENSMUSG00000021478', 'ENSMUSG00000022206', 'ENSMUSG00000022595', 'ENSMUSG00000022667', 'ENSMUSG00000022878', 'ENSMUSG00000022935', 'ENSMUSG00000023046', 'ENSMUSG00000023274', 'ENSMUSG00000024112', 'ENSMUSG00000024261', 'ENSMUSG00000024371', 'ENSMUSG00000024503', 'ENSMUSG00000024511', 'ENSMUSG00000024529', 'ENSMUSG00000024677', 'ENSMUSG00000024679', 'ENSMUSG00000025044', 'ENSMUSG00000025479', 'ENSMUSG00000026023', 'ENSMUSG00000026475', 'ENSMUSG00000026676', 'ENSMUSG00000026697', 'ENSMUSG00000026890', 'ENSMUSG00000027513', 'ENSMUSG00000028033', 'ENSMUSG00000028175', 'ENSMUSG00000030043', 'ENSMUSG00000030108', 'ENSMUSG00000030546', 'ENSMUSG00000030747', 'ENSMUSG00000030786', 'ENSMUSG00000031380', 'ENSMUSG00000031495', 'ENSMUSG00000031558', 'ENSMUSG00000032332', 'ENSMUSG00000033576', 'ENSMUSG00000034394', 'ENSMUSG00000034652', 'ENSMUSG00000034845', 'ENSMUSG00000035004', 'ENSMUSG00000035133', 'ENSMUSG00000035299', 'ENSMUSG00000035557', 'ENSMUSG00000036469', 'ENSMUSG00000037254', 'ENSMUSG00000038540', 'ENSMUSG00000038903', 'ENSMUSG00000039196', 'ENSMUSG00000040133', 'ENSMUSG00000040373', 'ENSMUSG00000040522', 'ENSMUSG00000040856', 'ENSMUSG00000041046', 'ENSMUSG00000041144', 'ENSMUSG00000041479', 'ENSMUSG00000042671', 'ENSMUSG00000042751', 'ENSMUSG00000043681', 'ENSMUSG00000044405', 'ENSMUSG00000046159', 'ENSMUSG00000046314', 'ENSMUSG00000046591', 'ENSMUSG00000047638', 'ENSMUSG00000048583', 'ENSMUSG00000050493', 'ENSMUSG00000050830', 'ENSMUSG00000051748', 'ENSMUSG00000052316', 'ENSMUSG00000052821', 'ENSMUSG00000052957', 'ENSMUSG00000052974', 'ENSMUSG00000053687', 'ENSMUSG00000054146', 'ENSMUSG00000054905', 'ENSMUSG00000056296', 'ENSMUSG00000056706', 'ENSMUSG00000058952', 'ENSMUSG00000059027', 'ENSMUSG00000059108', 'ENSMUSG00000059173', 'ENSMUSG00000059632', 'ENSMUSG00000060512', 'ENSMUSG00000061397', 'ENSMUSG00000061527', 'ENSMUSG00000061780', 'ENSMUSG00000062382', 'ENSMUSG00000062593', 'ENSMUSG00000063632', 'ENSMUSG00000063651', 'ENSMUSG00000066705', 'ENSMUSG00000067006', 'ENSMUSG00000067780', 'ENSMUSG00000068893', 'ENSMUSG00000069609', 'ENSMUSG00000070348', 'ENSMUSG00000071470', 'ENSMUSG00000071561', 'ENSMUSG00000074199', 'ENSMUSG00000074867', 'ENSMUSG00000078122', 'ENSMUSG00000078896', 'ENSMUSG00000078922', 'ENSMUSG00000079419', 'ENSMUSG00000079428', 'ENSMUSG00000086003', 'ENSMUSG00000091898', 'ENSMUSG00000092627', 'ENSMUSG00000096768', 'ENSMUSG00000097039', 'ENSMUSG00000099587', 'ENSMUSG00000100303', 'ENSMUSG00000101389', 'ENSMUSG00000102252', 'ENSMUSG00000102308', 'ENSMUSG00000105891', 'ENSMUSG00000111577', 'ENSMUSG00000112023', 'ENSMUSG00000112148', 'ENSMUSG00000112234', 'ENSMUSG00000118124', 'ENSMUSG00000120082']
# /var/folders/j2/645ctp717nv8rwbn2dsccyxh0000gn/T/ipykernel_31119/48160985.py:34: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   annotation = pandas.read_csv('/Users/adrian/software/kallisto/mouse_index_standard/t2g.txt', sep='\t', header=None)
# 49
# Klf4
# Emb
# Vdr
# Trp63
# Serinc2
# Slc16a3
# Urah
# Slc40a1
# Ptprc
# Pkp1
# Selp
# Spint1
# Siglec1
# Plbd1
# Cidec
# Hp
# Trim29
# Dpyd
# Asprv1
# Ly6d
# Vax2
# Lars2
# Krt80
# Tcfl5
# Igfbp2
# Mreg
# Saa3
# Apoc1
# Ppp1r13l
# S100a14
# Ifi209
# Zfp758
# Krt14
# Ccr2
# Sorl1
# Fam110d
# Sprr1a
# Lgals7
# Krt16
# Pkp3
# Dsp
# Krt6a
# C1qtnf3
# Dmkn
# mt-Atp8
# Zfp991
# Col6a5
# Rmrp
# Gm7072

# %%
input_dir = '/Users/adrian/research/bmcbf/029_orsay/results/001.degs/'

df = pandas.read_csv(input_dir+'effect_HET_vs_WT.woo.for.tsv', sep='\t', index_col=0)
dfup = df[df['log2FoldChange'] > 0]; dfdown = df[df['log2FoldChange'] < 0]
au = set(dfup.index); ad = set(dfdown.index)
print(len(au), len(ad))

df = pandas.read_csv(input_dir+'effect_HOM_vs_WT.woo.for.tsv', sep='\t', index_col=0)
dfup = df[df['log2FoldChange'] > 0]; dfdown = df[df['log2FoldChange'] < 0]
bu = set(dfup.index); bd = set(dfdown.index)
print(len(bu), len(bd))

df = pandas.read_csv(input_dir+'effect_VGA_vs_WT.woo.for.tsv', sep='\t', index_col=0)
dfup = df[df['log2FoldChange'] > 0]; dfdown = df[df['log2FoldChange'] < 0]
cu = set(dfup.index); cd = set(dfdown.index)
print(len(cu), len(cd))

sets = [au, ad, bu, bd, cu, cd]
labels = ['HETU', 'HETD', 'HOMU', 'HOMD', 'VGAU', 'VGAD']
mso = supervenn.supervenn(sets, labels, chunks_ordering='size',
                          side_plots=False, widths_minmax_ratio=0.03, 
                          reverse_sets_order=False, fontsize=12, color_cycle=['gold', 'gold', 'tab:red', 'tab:red', 'skyblue', 'skyblue'])

matplotlib.pyplot.show()
# Out:
# 1 3
# 123 69
# 218 12
