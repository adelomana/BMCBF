# %% [raw]
# The goal of this notebook is to explore the expression of the biomarkers defined as:

# %% [markdown]
# The signature analyzed were the pigmented signature (MITF, MLANA, TYR, TRPM1, DCT), the invasive signature (CCN1, LOXL2, WNT5A, TCF4, AXL, TNC), the SMC signature (CD36, DLX5, IP6K3, PAX3, TRIM67) and the NCSC-like signatures (NGFR, AQP1, GFRA2, L1CAM, SLC22A17).

# %%
import pandas, seaborn
import scipy, scipy.stats
import matplotlib, matplotlib.pyplot

# %%
#user defined variables
annotation_file = '/Users/adrian/software/kallisto/mouse_index_standard/annotation.tsv'
expression_file = '/Users/adrian/research/bmcbf/029_orsay/results/000.quantification/results/DESeq2_TPM_values.tsv'

pigmented = ['Mitf', 'Mlana', 'Tyr', 'Trpm1', 'Dct']
invasive = ['Ccn1', 'Loxl2', 'Wnt5a', 'Tcf4', 'Axl', 'Tnc']
mesenchymal = ["Cd36", "Dlx5", "Ip6k3", "Pax3", "Trim67"]
crest = ["Ngfr", "Aqp1", "Gfra2", "L1cam", "Slc22a17"]
biomarkers = pigmented + invasive + mesenchymal + crest
print(biomarkers)
# Out:
# ['Mitf', 'Mlana', 'Tyr', 'Trpm1', 'Dct', 'Ccn1', 'Loxl2', 'Wnt5a', 'Tcf4', 'Axl', 'Tnc', 'Cd36', 'Dlx5', 'Ip6k3', 'Pax3', 'Trim67', 'Ngfr', 'Aqp1', 'Gfra2', 'L1cam', 'Slc22a17']

# %%
# read info
anno = pandas.read_csv(annotation_file, sep='\t')
expression = pandas.read_csv(expression_file, sep='\t', index_col=0)

# %%
# manipulate expression

# %%
expression.index = expression.index.str.split('.').str[0]

print(expression.shape)
expression.drop(['P9T001', 'P9T004', 'P9T009'], axis=1, inplace=True)
print(expression.shape)
# Out:
# (34183, 34)
# (34183, 31)

# %%
rosetta = {}
for biomarker in biomarkers:
    info = anno[anno['external_gene_name'] == biomarker]
    hit = list(info['ensembl_gene_id'].values)[0]
    print(info)
    rosetta[biomarker] = hit
print(rosetta)
biomarker_names = list(rosetta.values())
# Out:
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 14867       14868  ENSMUSG00000035158               Mitf  protein_coding
#
#                                              description
# 14867  melanogenesis associated transcription factor ...
#       Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 6150        6151  ENSMUSG00000024806              Mlana  protein_coding
#
#                                      description
# 6150  melan-A [Source:MGI Symbol;Acc:MGI:108454]
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 10749       10750  ENSMUSG00000004651                Tyr  protein_coding
#
#                                         description
# 10749  tyrosinase [Source:MGI Symbol;Acc:MGI:98880]
#       Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 8131        8132  ENSMUSG00000030523              Trpm1  protein_coding
#
#                                             description
# 8131  transient receptor potential cation channel, s...
#       Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 5162        5163  ENSMUSG00000022129                Dct  protein_coding
#
#                                             description
# 5162  dopachrome tautomerase [Source:MGI Symbol;Acc:...
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 29345       29346  ENSMUSG00000028195               Ccn1  protein_coding
#
#                                              description
# 29345  cellular communication network factor 1 [Sourc...
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 10733       10734  ENSMUSG00000034205              Loxl2  protein_coding
#
#                                              description
# 10733  lysyl oxidase-like 2 [Source:MGI Symbol;Acc:MG...
#       Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 5178        5179  ENSMUSG00000021994              Wnt5a  protein_coding
#
#                                             description
# 5178  wingless-type MMTV integration site family, me...
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 10222       10223  ENSMUSG00000053477               Tcf4  protein_coding
#
#                                              description
# 10222  transcription factor 4 [Source:MGI Symbol;Acc:...
#       Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 7252        7253  ENSMUSG00000002602                Axl  protein_coding
#
#                                             description
# 7252  AXL receptor tyrosine kinase [Source:MGI Symbo...
#       Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 9726        9727  ENSMUSG00000028364                Tnc  protein_coding
#
#                                         description
# 9726  tenascin C [Source:MGI Symbol;Acc:MGI:101922]
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 20588       20589  ENSMUSG00000002944               Cd36  protein_coding
#
#                                             description
# 20588  CD36 molecule [Source:MGI Symbol;Acc:MGI:107899]
#       Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 9429        9430  ENSMUSG00000029755               Dlx5  protein_coding
#
#                                             description
# 9429  distal-less homeobox 5 [Source:MGI Symbol;Acc:...
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 16996       16997  ENSMUSG00000024210              Ip6k3  protein_coding
#
#                                              description
# 16996  inositol hexaphosphate kinase 3 [Source:MGI Sy...
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 72156       72157  ENSMUSG00000004872               Pax3  protein_coding
#
#                                           description
# 72156  paired box 3 [Source:MGI Symbol;Acc:MGI:97487]
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 21967       21968  ENSMUSG00000036913             Trim67  protein_coding
#
#                                              description
# 21967  tripartite motif-containing 67 [Source:MGI Sym...
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 70740       70741  ENSMUSG00000000120               Ngfr  protein_coding
#
#                                              description
# 70740  nerve growth factor receptor (TNFR superfamily...
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 17337       17338  ENSMUSG00000004655               Aqp1  protein_coding
#
#                                           description
# 17337  aquaporin 1 [Source:MGI Symbol;Acc:MGI:103201]
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 50484       50485  ENSMUSG00000022103              Gfra2  protein_coding
#
#                                              description
# 50484  glial cell line derived neurotrophic factor fa...
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 31049       31050  ENSMUSG00000031391              L1cam  protein_coding
#
#                                              description
# 31049  L1 cell adhesion molecule [Source:MGI Symbol;A...
#        Unnamed: 0     ensembl_gene_id external_gene_name    gene_biotype  \
# 32496       32497  ENSMUSG00000022199           Slc22a17  protein_coding
#
#                                              description
# 32496  solute carrier family 22 (organic cation trans...
# {'Mitf': 'ENSMUSG00000035158', 'Mlana': 'ENSMUSG00000024806', 'Tyr': 'ENSMUSG00000004651', 'Trpm1': 'ENSMUSG00000030523', 'Dct': 'ENSMUSG00000022129', 'Ccn1': 'ENSMUSG00000028195', 'Loxl2': 'ENSMUSG00000034205', 'Wnt5a': 'ENSMUSG00000021994', 'Tcf4': 'ENSMUSG00000053477', 'Axl': 'ENSMUSG00000002602', 'Tnc': 'ENSMUSG00000028364', 'Cd36': 'ENSMUSG00000002944', 'Dlx5': 'ENSMUSG00000029755', 'Ip6k3': 'ENSMUSG00000024210', 'Pax3': 'ENSMUSG00000004872', 'Trim67': 'ENSMUSG00000036913', 'Ngfr': 'ENSMUSG00000000120', 'Aqp1': 'ENSMUSG00000004655', 'Gfra2': 'ENSMUSG00000022103', 'L1cam': 'ENSMUSG00000031391', 'Slc22a17': 'ENSMUSG00000022199'}

# %%
df = expression.loc[biomarker_names]
df
# Out:
#                         P9T002       P9T003      P9T005      P9T006  \
# ENSMUSG00000035158    7.512801     6.405729    7.305249    6.643133
# ENSMUSG00000024806    0.704414     0.255398    0.341277    0.747098
# ENSMUSG00000004651    0.584955     1.219772    0.866577    0.354613
# ENSMUSG00000030523    0.097092     0.000000    0.019026    0.099710
# Ngfr     -0.462073 -0.154199  3.057679 -0.634659 -0.406158 -1.089454
# Aqp1     -0.637172  1.074355 -0.143500 -0.631935  0.184355 -0.336995
# Gfra2     0.079736 -0.449999 -0.037573 -1.070327 -0.226137 -0.180301
# L1cam    -1.348678  0.812791  2.240721 -0.500545 -1.043102 -1.125403
# Slc22a17 -1.151310  0.282168  0.155074 -1.114300 -0.437250 -0.571458
#
#             P9T033    P9T034
# Mitf     -2.179563 -1.572857
# Mlana    -0.581480 -0.460555
# Tyr       1.049646  0.080301
# Trpm1    -0.554247 -0.322273
# Dct       0.418824 -0.759874
# Ccn1     -0.346804 -0.706069
# Loxl2    -0.127666 -0.293323
# Wnt5a    -0.355713 -0.828230
# Tcf4      0.375811  0.434115
# Axl       1.837862 -0.276789
# Tnc       1.189196 -0.855724
# Cd36     -1.127347 -0.775854
# Dlx5     -0.805013 -0.805013
# Ip6k3    -0.706911  1.425257
# Pax3      0.513073  0.400882
# Trim67    0.917831 -1.104810
# Ngfr     -1.098142 -0.813535
# Aqp1      0.490557  0.674872
# Gfra2    -1.812325 -0.025213
# L1cam     0.568962 -0.137561
# Slc22a17 -0.061416  1.148821
#
# [21 rows x 31 columns]

# %%
group_dict = {}

# Group A: P9T002 to P9T008 (excluding P9T004 and P9T009)
for i in range(1, 10):
    if i not in [1, 4, 9]:
        sample_id = f"P9T{i:03d}"
        group_dict[sample_id] = "WT"

# Group B: P9T010 to P9T015
for i in range(10, 19):
    sample_id = f"P9T{i:03d}"
    group_dict[sample_id] = "HET"

# Group C: P9T020 to P9T025
for i in range(19, 31):
    sample_id = f"P9T{i:03d}"
    group_dict[sample_id] = "HOM"

for i in range(31, 35):
    sample_id = f"P9T{i:03d}"
    group_dict[sample_id] = "VGA"

# # (Optional) Preview
# for element in group_dict:
#     print(element, group_dict[element])

group_series = pandas.Series(group_dict).reindex(df_zscore.columns)
group_colors = group_series.map({'WT': 'gray', 'HET': 'gold', 'HOM': 'tab:red', 'VGA': 'skyblue'})

# %%
row_group_dict = {}

pigmented = ['Mitf', 'Mlana', 'Tyr', 'Trpm1', 'Dct']
invasive = ['Ccn1', 'Loxl2', 'Wnt5a', 'Tcf4', 'Axl', 'Tnc']

for element in pigmented:
    row_group_dict[element] = "tab:orange"

for element in invasive:
    row_group_dict[element] = "pink"

for element in mesenchymal:
    row_group_dict[element] = "skyblue"

for element in crest:
    row_group_dict[element] = "gray"

# Create a row color series from the row group dictionary
row_colors = pandas.Series(row_group_dict)

# %%
g = seaborn.clustermap(
    df_zscore,
    metric='euclidean',     # distance metric
    method='average',       # clustering method (e.g., single, complete, average, ward)
    cmap='bwr',            # color map (others: 'coolwarm', 'viridis', 'mako', 'rocket')
    standard_scale=None,    # or 0 (rows) or 1 (columns) if you didn't z-score earlier
    figsize=(7, 7),
    col_colors=group_colors,
    row_colors=row_colors,
    dendrogram_ratio=(0.2, 0.2),  # adjust size of dendrograms
    cbar_pos=(0.02, 0.8, 0.05, 0.18),  # colorbar position
    xticklabels=True,
    cbar_kws={'label': 'Z-score'},
    vmin=-2.5,
    vmax=2.5,
    yticklabels=True
)
matplotlib.pyplot.setp(g.ax_heatmap.get_yticklabels(), rotation=0)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
