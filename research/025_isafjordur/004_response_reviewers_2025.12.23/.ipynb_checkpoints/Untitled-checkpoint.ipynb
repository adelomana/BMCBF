# %% [raw]
# 1. i need the table of expression for all conditions
# 2. the genes for the cell cycle and apoptosis categories
# 3. the target genes of p53
# 4. the intersects
#
# skmel 3 x 4; u2os 2 x 2. See if u2os can go 3 x 3, but not sure it is doable. the testing was done with two, bc otherwise there was 191 DEGs

# %%
import pandas, csv, mygene

# %%
# 1. table of expression for all conditions

results_folder = '/Users/adrian/research/bmcbf/025_isafjordur/results/000_quantification/'
results_folder = '/Users/adrian/Library/CloudStorage/ProtonDrive-adrian.rvk@proton.me-folder/scratch/'
expression_file_skmel = results_folder + 'DESeq2_TPM_values.skmel.tsv'
expression_file_u2o2 = results_folder + 'DESeq2_TPM_values.u2.tsv'

expression_skmel = pandas.read_csv(expression_file_skmel, sep='\t', index_col=0)
expression_u2os = pandas.read_csv(expression_file_u2o2, sep='\t', index_col=0)

print(expression_skmel.shape, expression_u2os.shape)

full_expression = pandas.concat([expression_skmel, expression_u2os], axis=1)
print(full_expression.shape)

selected_columns = ['SkMel28-MITFKO_ev_skmel28_rep1', 'SkMel28-MITFKO_ev_skmel28_rep2','SkMel28-MITFKO_ev_skmel28_rep3', 'SkMel28-MITFKO_ev_skmel28_rep4',
       'SkMel28-MITFKO_mitf_x6_rep1', 'SkMel28-MITFKO_mitf_x6_rep3','SkMel28-MITFKO_mitf_x6_rep4', 
        'U2-1_Sc_UT', 'U2-2_Sc_UT', 'U2-3_Sc_UT',
        'U2-1_siMi_UT', 'U2-2_siMi_UT', 'U2-3_siMi_UT']

expression = full_expression.loc[:, selected_columns]
expression
# Out:
# (39546, 7) (39546, 18)
# (39546, 25)
#                  SkMel28-MITFKO_ev_skmel28_rep1  \
# ENSG00000000003                        9.097209
# ENSG00000000005                        0.000000
# ENSG00000000419                      152.065078
# ENSG00000000457                        4.644776
# ENSG00000000460                       20.780175
# ...                                         ...
# ENSG00000291297                        5.742134
# ENSG00000291298                        0.000000
# ENSG00000291299                        1.784678
# ENSG00000291300                        0.000000
# ENSG00000291301                        0.000000
#
#                  SkMel28-MITFKO_ev_skmel28_rep2  \
# ENSG00000000003                        9.806654
# ENSG00000000005                        0.000000
# ENSG00000000419                      146.963798
# ENSG00000000457                        3.992320
# ENSG00000000460                       22.200583
# ...                                         ...
# ENSG00000291297                        5.220425
# ENSG00000291298                        0.000000
# ENSG00000291299                        1.767580
# ENSG00000291300                        0.000000
# ENSG00000291301                        0.000000
#
#                  SkMel28-MITFKO_ev_skmel28_rep3  \
# ENSG00000000003                       12.244351
# ENSG00000000005                        0.000000
# ENSG00000000419                      159.427516
# ENSG00000000457                        6.102643
# ENSG00000000460                       30.912937
# ...                                         ...
# ENSG00000291297                        6.054220
# ENSG00000291298                        0.000000
# ENSG00000291299                        1.662962
# ENSG00000291300                        0.000000
# ENSG00000291301                        0.000000
#
#                  SkMel28-MITFKO_ev_skmel28_rep4  SkMel28-MITFKO_mitf_x6_rep1  \
# ENSG00000000003                       12.179835                    17.984601
# ENSG00000000005                        0.000000                     0.000000
# ENSG00000000419                      180.241348                   197.693333
# ENSG00000000457                        3.590144                     5.672788
# ENSG00000000460                       20.707054                    26.297054
# ...                                         ...                          ...
# ENSG00000291297                        5.305273                     2.120733
# ENSG00000291298                        0.000000                     0.000000
# ENSG00000291299                        2.593021                     0.870331
# ENSG00000291300                        0.000000                     0.000000
# ENSG00000291301                        0.000000                     0.000000
#
#                  SkMel28-MITFKO_mitf_x6_rep3  SkMel28-MITFKO_mitf_x6_rep4  \
# ENSG00000000003                    12.499056                    10.895395
# ENSG00000000005                     0.000000                     0.000000
# ENSG00000000419                   144.099788                   136.583522
# ENSG00000000457                     4.962348                     4.242799
# ENSG00000000460                    17.887952                    14.196562
# ...                                      ...                          ...
# ENSG00000291297                     2.756115                     2.122733
# ENSG00000291298                     0.000000                     0.944026
# ENSG00000291299                     2.213504                     1.361509
# ENSG00000291300                     0.000000                     0.000000
# ENSG00000291301                     0.000000                     0.000000
#
#                  U2-1_Sc_UT  U2-2_Sc_UT  U2-3_Sc_UT  U2-1_siMi_UT  \
# ENSG00000000003   30.818057    5.939035   28.165731      6.893577
# ENSG00000000005    0.000000    0.000000    0.043649      0.000000
# ENSG00000000419  112.914933   75.822065  107.421701     68.466391
# ENSG00000000457    2.598995   10.594728    2.507932     10.456216
# ENSG00000000460   32.056208   23.911539   28.125365     16.831813
# ...                     ...         ...         ...           ...
# ENSG00000291297    4.408266    0.545854    4.523390      0.229724
# ENSG00000291298    0.000000    0.000000    0.000000      0.000000
# ENSG00000291299    1.743303    2.385269    2.397874      3.476740
# ENSG00000291300    0.455893    0.230373    0.362591      0.206109
# ENSG00000291301    0.000000    0.001709    0.010073      0.005390
#
#                  U2-2_siMi_UT  U2-3_siMi_UT
# ENSG00000000003     40.127345     36.374311
# ENSG00000000005      0.020145      0.024416
# ENSG00000000419     87.365983     84.883315
# ENSG00000000457      4.589684      4.514144
# ENSG00000000460     11.772422     11.618076
# ...                       ...           ...
# ENSG00000291297      2.258105      4.005492
# ENSG00000291298      0.000000      0.000000
# ENSG00000291299      2.271456      2.192518
# ENSG00000291300      0.314552      0.284173
# ENSG00000291301      0.001859      0.002266
#
# [39546 rows x 13 columns]

# %%
# 2. the genes for the cell cycle and apoptosis categories
# the file was retrieved from enrichr as reactome pathways 2024

rows = []
with open('Reactome_Pathways_2024.txt', newline='') as f:
    reader = csv.reader(f, delimiter='\t')   # adjust delimiter
    for row in reader:
        rows.append(row)

df = pandas.DataFrame(rows)
mask = df[0].str.contains('TP53 Regulates', case=False, na=False)
new = df[mask]
new = new.set_index(0)
new

values = new.loc['TP53 Regulates Transcription of Cell Cycle Genes', :].dropna().to_list()
genes_cycle = [value for value in values if value != '']
print(len(genes_cycle), genes_cycle[:5])

values = new.loc['TP53 Regulates Transcription of Cell Death Genes', :].dropna().to_list()
genes_death = [value for value in values if value != '']
print(len(genes_death), genes_death[:5])

values = new.loc['TP53 Regulates Transcription of DNA Repair Genes', :].dropna().to_list()
genes_repair = [value for value in values if value != '']
print(len(genes_repair), genes_repair[:5])
# Out:
# 49 ['ARID3A', 'CNOT11', 'CNOT10', 'CDC25C', 'CNOT6']
# 44 ['ZNF420', 'CREBBP', 'PRELID1', 'APAF1', 'BNIP3L']
# 62 ['JUN', 'SUPT16H', 'GTF2F1', 'MSH2', 'GTF2F2']

# %%
# 3. convert gene symbols into ensembls

mg = mygene.MyGeneInfo()

out = mg.querymany(genes_repair, scopes='symbol', fields='ensembl.gene', species='human', as_dataframe=True)
out = out.explode('ensembl.gene')
ids = out['ensembl.gene'].dropna().unique().tolist()
print(len(ids), ids[:5])
# Out:
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# 54 ['ENSG00000177606', 'ENSG00000092201', 'ENSG00000125651', 'ENSG00000095002', 'ENSG00000188342']

# %%
nan_rows = out[out['ensembl.gene'].isna()]
nan_rows
# Out:
#          _id     _score ensembl.gene  \
# query
# CDK7    1022  17.027145          NaN
# GTF2H1  2965  17.556274          NaN
# GTF2H2  2966  18.304321          NaN
# GTF2H4  2968  17.830267          NaN
# MDC1    9656  17.913400          NaN
# CTDP1   9150  17.628109          NaN
# POLR2A  5430  17.732336          NaN
# NELFE   7936  17.879396          NaN
#
#                                                   ensembl
# query
# CDK7    [{'gene': 'ENSG00000277273'}, {'gene': 'ENSG00...
# GTF2H1  [{'gene': 'ENSG00000288114'}, {'gene': 'ENSG00...
# GTF2H2  [{'gene': 'ENSG00000276910'}, {'gene': 'ENSG00...
# GTF2H4  [{'gene': 'ENSG00000226384'}, {'gene': 'ENSG00...
# MDC1    [{'gene': 'ENSG00000234012'}, {'gene': 'ENSG00...
# CTDP1   [{'gene': 'ENSG00000060069'}, {'gene': 'ENSG00...
# POLR2A  [{'gene': 'ENSG00000181222'}, {'gene': 'ENSG00...
# NELFE   [{'gene': 'ENSG00000206357'}, {'gene': 'ENSG00...

# %%
out.head(50)
# Out:
#             _id     _score     ensembl.gene  \
# query
# JUN        3725  17.568882  ENSG00000177606
# SUPT16H   11198  17.796005  ENSG00000092201
# GTF2F1     2962  17.839700  ENSG00000125651
# MSH2       4436  17.367363  ENSG00000095002
# GTF2F2     2963  18.219427  ENSG00000188342
# CDK9       1025  17.055676  ENSG00000136807
# CDK7       1022  17.027145              NaN
# RAD51D     5892  17.145338  ENSG00000185379
# FANCD2     2177  17.074186  ENSG00000144554
# ATM         472  17.613213  ENSG00000149311
# CDK12     51755  17.081514  ENSG00000167258
# CDK13      8621  17.631947  ENSG00000065883
# ATR         545  17.598259  ENSG00000175054
# TP53       7157  18.047026  ENSG00000141510
# ATF2       1386  17.522058  ENSG00000115966
# CCNK       8812  17.598066  ENSG00000090061
# CCNT2       905  18.194134  ENSG00000082258
# CCNT1       904  17.693070  ENSG00000129315
# ELL        8178  17.672325  ENSG00000105656
# CCNH        902  17.592106  ENSG00000134480
# SUPT4H1    6827  17.552015  ENSG00000213246
# BRCA1       672  18.194382  ENSG00000012048
# CHEK1      1111  17.635342  ENSG00000149554
# NELFCD    51497  17.601840  ENSG00000101158
# PMS2       5395  17.021480  ENSG00000122512
# FANCI     55215  17.069597  ENSG00000140525
# MLH1       4292  16.890053  ENSG00000076242
# ELOA2     51224  22.926104  ENSG00000206181
# FOS        2353  18.015951  ENSG00000170345
# GTF2H1     2965  17.556274              NaN
# GTF2H2     2966  18.304321              NaN
# SSRP1      6749  18.195292  ENSG00000149136
# FANCC      2176  17.581844  ENSG00000158169
# GTF2H3     2967  17.566465  ENSG00000111358
# GTF2H4     2968  17.830267              NaN
# GTF2H5   404672  17.614746  ENSG00000272047
# SUPT5H     6829  17.707144  ENSG00000196235
# DDB2       1643  17.674030  ENSG00000134574
# ERCC2      2068  17.734800  ENSG00000104884
# ERCC3      2071  17.598066  ENSG00000163161
# TCEA1      6917  17.593042  ENSG00000187735
# MNAT1      4331  17.557283  ENSG00000020426
# MDC1       9656  17.913400              NaN
# CTDP1      9150  17.628109              NaN
# NELFA      7469  17.592638  ENSG00000185049
# POLR2A     5430  17.732336              NaN
# POLR2B     5431  17.507795  ENSG00000047315
# POLR2C     5432  17.492445  ENSG00000102978
# POLR2D     5433  17.283363  ENSG00000144231
# POLR2E     5434  18.026253  ENSG00000099817
#
#                                                    ensembl
# query
# JUN                                                    NaN
# SUPT16H                                                NaN
# GTF2F1                                                 NaN
# MSH2                                                   NaN
# GTF2F2                                                 NaN
# CDK9                                                   NaN
# CDK7     [{'gene': 'ENSG00000277273'}, {'gene': 'ENSG00...
# RAD51D                                                 NaN
# FANCD2                                                 NaN
# ATM                                                    NaN
# CDK12                                                  NaN
# CDK13                                                  NaN
# ATR                                                    NaN
# TP53                                                   NaN
# ATF2                                                   NaN
# CCNK                                                   NaN
# CCNT2                                                  NaN
# CCNT1                                                  NaN
# ELL                                                    NaN
# CCNH                                                   NaN
# SUPT4H1                                                NaN
# BRCA1                                                  NaN
# CHEK1                                                  NaN
# NELFCD                                                 NaN
# PMS2                                                   NaN
# FANCI                                                  NaN
# MLH1                                                   NaN
# ELOA2                                                  NaN
# FOS                                                    NaN
# GTF2H1   [{'gene': 'ENSG00000288114'}, {'gene': 'ENSG00...
# GTF2H2   [{'gene': 'ENSG00000276910'}, {'gene': 'ENSG00...
# SSRP1                                                  NaN
# FANCC                                                  NaN
# GTF2H3                                                 NaN
# GTF2H4   [{'gene': 'ENSG00000226384'}, {'gene': 'ENSG00...
# GTF2H5                                                 NaN
# SUPT5H                                                 NaN
# DDB2                                                   NaN
# ERCC2                                                  NaN
# ERCC3                                                  NaN
# TCEA1                                                  NaN
# MNAT1                                                  NaN
# MDC1     [{'gene': 'ENSG00000234012'}, {'gene': 'ENSG00...
# CTDP1    [{'gene': 'ENSG00000060069'}, {'gene': 'ENSG00...
# NELFA                                                  NaN
# POLR2A   [{'gene': 'ENSG00000181222'}, {'gene': 'ENSG00...
# POLR2B                                                 NaN
# POLR2C                                                 NaN
# POLR2D                                                 NaN
# POLR2E                                                 NaN

# %%
# go directly to do the heatmap

# %%
mask = df[0].str.contains('TP53 Regulates', case=False, na=False)
df[mask]
# Out:
#                                                    0    1         2     \
# 1860                     TP53 Regulates Metabolic Genes           G6PD
# 1861  TP53 Regulates Transcription of Caspase Activa...           TP73
# 1862   TP53 Regulates Transcription of Cell Cycle Genes         ARID3A
# 1863   TP53 Regulates Transcription of Cell Death Genes         ZNF420
# 1864   TP53 Regulates Transcription of DNA Repair Genes            JUN
# 1865  TP53 Regulates Transcription of Death Receptor...           TP73
# 1866  TP53 Regulates Transcription of Genes Involved...         ZNF420
# 1867  TP53 Regulates Transcription of Genes Involved...         CDKN1B
# 1868  TP53 Regulates Transcription of Genes Involved...           PCNA
# 1869  TP53 Regulates Transcription of Additional Cel...         CNOT6L
# 1870  TP53 Regulates Transcription of Cell Death Gen...       PPP1R13B
#
#           3         4        5        6          7          8          9     \
# 1860      GPX2     TIGAR      GSR   TXNRD1       TSC2       TSC1     PRKAB1
# 1861     CASP6     APAF1   CASP10    CRADD      CASP2        ATM      NLRC4
# 1862    CNOT11    CNOT10   CDC25C    CNOT6      CNOT7       RBL1      CNOT8
# 1863    CREBBP   PRELID1    APAF1   BNIP3L      CRADD     IGFBP3  TNFRSF10D
# 1864   SUPT16H    GTF2F1     MSH2   GTF2F2       CDK9       CDK7     RAD51D
# 1865  PPP1R13B       FAS   IGFBP3  TMEM219  TNFRSF10D  TNFRSF10C  TNFRSF10B
# 1866    CREBBP  PPP1R13B  PRELID1   BNIP3L   TP53INP1     TRIAP1       BBC3
# 1867    CDKN1A    ARID3A    CCNA2    CCNA1      PCBP4      CCNE2      CCNE1
# 1868   GADD45A     AURKA    PRMT1   CDC25C       RBL1      TFDP1      CCNB1
# 1869      NPM1      BTG2     PLK3     PLK2     CNOT11     CNOT10     CDC25C
# 1870       CHM   RABGGTB    NDRG1     TP73    BCL2L14    RABGGTA     TP53I3
#
#       ... 2606 2607 2608 2609 2610 2611 2612 2613 2614 2615
# 1860  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1861  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1862  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1863  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1864  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1865  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1866  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1867  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1868  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1869  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1870  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [11 rows x 2616 columns]
