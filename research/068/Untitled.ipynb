# %%
import decoupler as dc
interact = dc.op.collectri(organism='human')

# %%
interact[interact['target'] == 'DIO2']
# Out:
#        source target  weight                      resources  \
# 2570     TTF1   DIO2     1.0                          ExTRI
# 5957    GATA4   DIO2     1.0                          ExTRI
# 5958   NKX2-5   DIO2     1.0                   ExTRI;GEREDB
# 11009   STAT3   DIO2     1.0             ExTRI;NTNU.Curated
# 11010  STAT5A   DIO2     1.0                          ExTRI
# 16310  NFATC1   DIO2     1.0                          ExTRI
# 16312   MEF2A   DIO2     1.0                          ExTRI
# 16314    MITF   DIO2     1.0                          ExTRI
# 17891   NR1H3   DIO2     1.0                          ExTRI
# 20613   CREB1   DIO2     1.0  DoRothEA-A;ExTRI;NTNU.Curated
# 22607   CEBPA   DIO2     1.0             ExTRI;NTNU.Curated
# 22608   CEBPB   DIO2     1.0                          ExTRI
# 22609   CEBPG   DIO2     1.0                          ExTRI
# 27943     SP1   DIO2     1.0                          ExTRI
# 27944     SP3   DIO2     1.0                          ExTRI
# ...
