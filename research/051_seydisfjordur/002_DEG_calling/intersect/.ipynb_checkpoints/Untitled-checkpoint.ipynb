# %%
import pandas, matplotlib_venn, matplotlib

# %%
a = pandas.read_csv('deseq2.txt', sep='\t')
a
# Out:
#                     baseMean  log2FoldChange     lfcSE         stat  \
# ENSG00000206195  2125.950077        8.364166  0.269284  1666.887104
# ENSG00000222036  1761.313071        9.107035  0.342612  1884.094656
# ENSG00000274827  1248.271326       10.956396  0.738978  1114.820318
# ENSG00000101680  1953.637473        7.479655  0.238034  1112.744468
# ENSG00000103187  4088.417395       -3.384177  0.100426   987.493348
# ...                      ...             ...       ...          ...
# ENSG00000166707   128.492104        1.145448  0.450087     6.309517
# ENSG00000154309    89.076810        1.052647  0.417704     6.261650
# ENSG00000198417    11.075942       -3.684413  1.397825     6.260452
# ENSG00000229474    57.360827       -1.080961  0.429935     6.255025
# ENSG00000214940    59.262902       -1.766095  0.685376     6.252078
#
#                         pvalue           padj       ensembl_id  gene_name  \
# ENSG00000206195   0.000000e+00   0.000000e+00  ENSG00000206195     DUXAP8
# ...

# %%
b = pandas.read_csv('sleuth.txt', sep='\t')
b
# Out:
#                target_id      V3          V4  V5         V6         V7 V8  \
# 1     ENSG00000206195.11  DUXAP8  DUXAP8-201  22   15784968   15819165  +
# 10    ENSG00000137959.17  IFI44L  IFI44L-201   1   78620448   78646145  +
# 23    ENSG00000115232.14   ITGA4   ITGA4-201   2  181457428  181509805  +
# 32    ENSG00000140937.14   CDH11   CDH11-201  16   64943753   65122063  -
# 40    ENSG00000026508.21    CD44    CD44-201  11   35139171   35232402  +
# ...                  ...     ...         ...  ..        ...        ... ..
# 5233   ENSG00000089558.9   KCNH4   KCNH4-202  17   42156891   42181081  -
# 5272   ENSG00000243414.6  TICAM2  TICAM2-201   5  115578496  115602479  -
# 5295   ENSG00000287168.3     NaN         NaN   9   62801534   62802699  -
# 5312   ENSG00000290917.1  RAET1K  RAET1K-202   6  149998019  150005166  -
# 5318   ENSG00000178531.6   CTXN1   CTXN1-201  19    7924491    7926135  -
#
#       num_aggregated_transcripts  sum_mean_obs_counts          pval  \
# ...

# %%
x = set(a.index)
print(len(x))
# Out:
# 1358

# %%
y = set(b['ensembl_id'])
print(len(y))
# Out:
# 820

# %%
results = matplotlib_venn.venn2(subsets = [x, y], set_labels=['DESeq2', 'sleuth'], set_colors=['tab:orange', 'skyblue'], alpha=0.7)
matplotlib_venn.venn2_circles(subsets=[x, y])  

#matplotlib.pyplot.show()
matplotlib.pyplot.savefig('venn.svg')

# %%
common = list(x & y)
print(len(common))
df = pandas.DataFrame(common, columns=['common'])
df.to_csv('my_list.txt', sep='\t', index=False)
# Out:
# 803
