# %%
from matplotlib_venn import venn2,venn2_circles 
from matplotlib import pyplot as plt 

"""
374 afactor.txt
1124 ahistone.txt
2305 mfactor.txt
771 mhistone.txt
"""

totalA = 374 + 1124 # 1498
totalM = 2305 + 771 # 3076
print(totalA)
print(totalM)


# a vs m: 1201, implies unique are 1498 - 1201: 297
# m vs a: 2076, implies unique are 3076 - 2076: 1000
# common are 1498 - 297: 1201

set_sizes = (297, 3076-1201, 1201)
  
# depict venn diagram 
venn2(subsets = set_sizes, 
      set_labels = ('MITFA',  
                    'MITFM'), 
      set_colors=("skyblue", 
                  "tab:orange"),alpha=0.7) 
  
# add outline 
venn2_circles(subsets=set_sizes)  
#plt.savefig('venn.svg')
#plt.close()
# Out:
# 1498
# 3076
# ...
