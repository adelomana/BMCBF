# %%
# add A

# read M
# get the unique and the specials 
# get the top one

# %%
import pandas

# %%
target_file = '/Users/adrian/research/004.keilir/results/production/GeneOntology/MITFA_untreated_01_all-homer_GO/wikipathways.txt'
dfa = pandas.read_csv(target_file, sep='\t')

target_file = '/Users/adrian/research/004.keilir/results/production/GeneOntology/MITFM_untreated_01_all-homer_GO/wikipathways.txt'
dfm = pandas.read_csv(target_file, sep='\t')

lista = list(dfa['Term'])
listm = list(dfm['Term'])
common = [value for value in lista if value in listm]
print(len(lista), len(listm), len(common))

# add A

# read M
# get the unique and the specials 
# get the top one
# Out:
# 366 366 366

# %%
common
# Out:
# ['EGF/EGFR Signaling Pathway',
#  'Integrin-mediated Cell Adhesion',
#  'Insulin Signaling',
#  'Association Between Physico-Chemical Features and Toxicity Associated Pathways',
#  'MAPK Signaling Pathway',
#  'B Cell Receptor Signaling Pathway',
#  'Angiopoietin Like Protein 8 Regulatory Pathway',
#  'Prolactin Signaling Pathway',
#  'TGF-beta Signaling Pathway',
#  'Apoptosis-related network due to altered Notch3 in ovarian cancer',
#  'ErbB Signaling Pathway',
#  'Focal Adhesion',
#  'Regulation of Actin Cytoskeleton',
#  'Arrhythmogenic Right Ventricular Cardiomyopathy',
#  'Brain-Derived Neurotrophic Factor (BDNF) signaling pathway',
#  'Androgen receptor signaling pathway',
#  'Wnt Signaling Pathway Netpath',
#  'Canonical and Non-Canonical TGF-B signaling',
#  'Nanoparticle-mediated activation of receptor signaling',
#  'Adipogenesis',
#  'Primary Focal Segmental Glomerulosclerosis FSGS',
#  'T-Cell antigen Receptor (TCR)  Signaling Pathway',
# ...
