# %%
import pandas, numpy

# %%
import scipy, scipy.signal

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(2/3), 9*(2/3)), 
                            'axes.labelsize':20
                           })

# %% [markdown]
# # 0. user-defined variables

# %%
input_file = 'DESeq2_TPM_values.tsv'

# %% [markdown]
# # 1. read expression

# %%
expression = pandas.read_csv(input_file, sep='\t', index_col=0)
print(expression.shape)
expression
# Out:
# (20196, 15)
#                                  h1M8_1     h1M8_2     h1M8_3    h2F14_1  \
# FBgn0000008                    7.888992   2.404364   7.641325   4.496739
# FBgn0000014                   20.584356   9.116074  16.522137  15.028010
# FBgn0000015                    4.750318   2.421290   4.041314   3.888815
# FBgn0000017                   18.593702  10.642545  16.094865  12.066664
# FBgn0000018                    7.344876   5.077850   5.495519   6.130012
# ...                                 ...        ...        ...        ...
# RR51048_transposable_element   0.000000   0.000000   0.000000   0.000000
# RR51093_transposable_element   0.000000   0.000000   0.378845   0.000000
# RR51475_transposable_element   0.731425   1.404666   2.041584   0.587566
# RR51477_transposable_element   0.009972   0.017888   0.021606   0.021574
# RR51478_transposable_element   0.000000   0.000000   0.000000   0.000000
#
#                                 h2F14_2    h2F14_3     h2M8_1     h2M8_2  \
# ...

# %% [markdown]
# # 3. filter and transform

# %%
substantial_expression = expression[expression.max(axis=1) >= 2]
high_expression = expression[expression.max(axis=1) >= 100]

print(substantial_expression.shape)
print(high_expression.shape)
# Out:
# (11396, 15)
# (1458, 15)

# %%
log_expression = numpy.log2(substantial_expression + 1) # why plus one?
log_expression
# Out:
#                                 h1M8_1    h1M8_2    h1M8_3       h2F14_1  \
# FBgn0000008                   3.152020  1.767385  3.111253  2.458576e+00
# FBgn0000014                   4.431914  3.338578  4.131107  4.002523e+00
# FBgn0000015                   2.523642  1.774540  2.333800  2.289485e+00
# FBgn0000017                   4.292318  3.541335  4.095491  3.707819e+00
# FBgn0000018                   3.060891  2.603561  2.699445  2.833905e+00
# ...                                ...       ...       ...           ...
# RR48348_transposable_element  1.525852  1.776530  2.084070  5.632261e+00
# RR48391_transposable_element  1.038722  1.076630  1.424597  3.429379e-09
# RR48399_transposable_element  0.022713  0.198796  0.170703  1.514366e-03
# RR48532_transposable_element  2.833434  3.056547  3.899365  4.581070e+00
# RR51475_transposable_element  0.791960  1.265837  1.604823  6.668165e-01
#
#                                h2F14_2   h2F14_3    h2M8_1    h2M8_2  \
# ...

# %% [markdown]
# # 4. visualize substantial expression

# %%
number_of_bins = 100
found_max = numpy.max(log_expression)
print(found_max)

hist, bin_edges = numpy.histogram(log_expression, bins=number_of_bins, range=(0, found_max), density=True)
half_bin = (bin_edges[1] - bin_edges[0])/2
x = bin_edges + half_bin
x = x[:-1]

matplotlib.pyplot.plot(x, hist, 'o', alpha=2/3, mec='none', color='skyblue')

matplotlib.pyplot.xlabel('Expression [log$_2$ (TPM + 1)]')
matplotlib.pyplot.ylabel('Probability density')
matplotlib.pyplot.grid(ls=':')

matplotlib.pyplot.tight_layout()
# Out:
# 15.54006771233757

# %%
for column in log_expression.columns:
    sample_expression = log_expression[column]
    
    number_of_bins = 100
    found_max = numpy.max(sample_expression)
    
    hist, bin_edges = numpy.histogram(sample_expression, bins=number_of_bins, range=(0, found_max), density=True)
    half_bin = (bin_edges[1] - bin_edges[0])/2
    x = bin_edges + half_bin
    x = x[:-1]
    
    matplotlib.pyplot.plot(x, hist, 'o', alpha=2/3, mec='none', color='skyblue')

matplotlib.pyplot.xlabel('Expression [log$_2$ (TPM + 1)]')
matplotlib.pyplot.ylabel('Probability density')
matplotlib.pyplot.grid(ls=':')

matplotlib.pyplot.tight_layout()

# %%
for column in log_expression.columns:
    sample_expression = log_expression[column]
    
    number_of_bins = 100
    found_max = numpy.max(sample_expression)
    found_max = 16
    
    hist, bin_edges = numpy.histogram(sample_expression, bins=number_of_bins, range=(0, found_max), density=True)
    half_bin = (bin_edges[1] - bin_edges[0])/2
    x = bin_edges + half_bin
    x = x[:-1]
    
    matplotlib.pyplot.plot(x, hist, 'o', alpha=2/3, mec='none', color='skyblue')
    
    margin = 5
    plotting_x = x[margin:number_of_bins-margin]
    plotting_hist = hist[margin:number_of_bins-margin]
    
    yhat = scipy.signal.savgol_filter(plotting_hist, 51, 3)
    matplotlib.pyplot.plot(plotting_x, yhat, '-', lw=4, alpha=3/4, color='gold')

matplotlib.pyplot.xlabel('Expression [log$_2$ (TPM + 1)]')
matplotlib.pyplot.ylabel('Probability density')
matplotlib.pyplot.grid(ls=':')

#matplotlib.pyplot.ylim(-0.05, 0.2)

matplotlib.pyplot.tight_layout()

matplotlib.pyplot.xlabel('Expression [log$_2$ (TPM + 1)]')
matplotlib.pyplot.ylabel('Probability density')
matplotlib.pyplot.grid(ls=':')

matplotlib.pyplot.tight_layout()
